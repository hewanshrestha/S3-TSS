# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import random
from tqdm.auto import tqdm
from torch.utils.data import Subset
random.seed(42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset_path = '/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/data/EuroSAT'   ### Change the path when you are running the code @hewan
batch_size = 64  
num_epochs = 20  
lr = 0.001  
# weight_decay = 0.0005
init_idx = 0
backbone = [models.resnet50, models.resnet18][1] # 0: resnet50, 1: resnet18
init = [None, models.ResNet18_Weights.IMAGENET1K_V1] # 0: None, 1: IMAGENET1K_V1, 2: IMAGENET1K_V2
img_size = 64
training_type = ['fine_tuning', 'linear_probe']

# %% [markdown]
# TO DO:
# - Data Description, train, test split and their distribution

# %%
def select_percentage_of_train_dataset(dataset, percentage):
    class_counts = {}
    indices_by_class = {}

    # Count the number of samples in each class
    for idx, (_, label) in enumerate(dataset):
        if label not in class_counts:
            class_counts[label] = 0
            indices_by_class[label] = []
        class_counts[label] += 1
        indices_by_class[label].append(idx)

    selected_indices = []

    # Select a percentage of samples from each class
    for _, indices in indices_by_class.items():
        num_samples = int(len(indices) * percentage)
        selected_samples = random.sample(indices, num_samples)
        selected_indices.extend(selected_samples)

    selected_data = Subset(dataset, selected_indices)
    return selected_data


def model_def(backbone, training_type, weights, num_classes, device = torch.device("cuda" if torch.cuda.is_available() else "cpu")):
    model = backbone(weights=weights)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, num_classes)
    if training_type == 'fine_tuning':
        for param in model.parameters():
            param.requires_grad = True
    elif training_type == 'linear_probe':
        for param in model.parameters():
            param.requires_grad = False
        for param in model.fc.parameters():
            param.requires_grad = True
    else:
        raise ValueError('Invalid training type!')
    return model.to(device)

def train_model(model, selected_train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir):
    train_loss = []
    train_accuracy = []
    test_loss = []
    test_accuracy = []
    best_acc = 0.0
    best_loss = float('inf')

    for epoch in range(1, num_epochs + 1):
        print(f'Epoch {epoch} of {num_epochs}')
        correct = 0
        iterations = 0
        iter_loss = 0.0

        model.train()  

        for i, (inputs, labels) in enumerate(selected_train_loader):
            if device:
                inputs = inputs.to(device)
                labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            iter_loss += loss.item() 
            optimizer.zero_grad() 
            loss.backward()  
            optimizer.step()  

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum()
            iterations += 1

        scheduler.step()

        train_loss.append(iter_loss / iterations)
        train_accuracy.append((100 * correct / len(selected_train_loader.dataset)))

        test_acc, test_losses = evaluate_model(model, test_loader, criterion, device)

        test_loss.append(test_losses)
        test_accuracy.append(test_acc)

        print(f'Epoch {epoch} Train results: Loss={train_loss[-1]:.4f} | Accuracy={train_accuracy[-1]:.2f}%')
        print(f'Epoch {epoch} Test results: Loss={test_loss[-1]:.4f} | Accuracy={test_accuracy[-1]:.2f}%\n')

        if test_acc > best_acc:
            best_acc = test_acc
            # torch.save(model.state_dict(), os.path.join(save_dir, 'best_acc_model.pth'))

        if test_losses < best_loss:
            best_loss = test_losses
            # torch.save(model.state_dict(), os.path.join(save_dir, 'best_loss_model.pth'))

    # Save the final model
    # torch.save(model.state_dict(), os.path.join(save_dir, 'final_model.pth'))

    return train_loss, train_accuracy, test_loss, test_accuracy


def evaluate_model(model, test_loader, criterion, device):
    model.eval()  
    test_loss = 0.0
    correct = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            if device:
                inputs = inputs.cuda()
                labels = labels.cuda()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100.0 * correct / len(test_loader.dataset)

    return accuracy, test_loss

# %%
#Data transforms and dataloaders
data_transforms = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


train_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'train'), data_transforms)
train_loader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
test_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'test'), data_transforms)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False, num_workers=2, pin_memory=True)

num_classes = len(train_dataset.classes)
class_names = train_dataset.classes
print("Classes:", class_names)
# Out:
# Classes: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %%
#count the number of images in each class
from collections import Counter
print(dict(Counter(test_dataset.targets)))
# Out:
# {0: 300, 1: 300, 2: 300, 3: 250, 4: 250, 5: 200, 6: 250, 7: 300, 8: 250, 9: 300}

# %%
#list with the percentage of the dataset to be used
percentage_list = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]

# %%
save_dir = "/home/idisc02/Desktop/Hewan/hlcv/Why-Self-Supervision-in-Time/src/models/weights"
train_acc_dict_percentage = {}
test_acc_dict_percentage = {}
train_loss_dict_percentage = {}
test_loss_dict_percentage = {}

for k in tqdm(init):
    print(k)
    for j in tqdm(training_type):
        print(j)
        for i in tqdm(range(len(percentage_list))):
            print(f'Percentage of the dataset used: {percentage_list[i]}')
            model = model_def(backbone, j, k, num_classes, device)
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
            scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
            selected_train_dataset = select_percentage_of_train_dataset(train_dataset, percentage_list[i])
            selected_train_loader = DataLoader(selected_train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
            train_loss, train_accuracy, test_loss, test_accuracy = train_model(model, selected_train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir)

            train_acc_dict_percentage[f"{k}_{j}_{percentage_list[i]}"] = train_accuracy
            test_acc_dict_percentage[f"{k}_{j}_{percentage_list[i]}"] = test_accuracy
            train_loss_dict_percentage[f"{k}_{j}_{percentage_list[i]}"] = train_loss
            test_loss_dict_percentage[f"{k}_{j}_{percentage_list[i]}"] = test_loss
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# None
#   0%|          | 0/2 [00:00<?, ?it/s]
# fine_tuning
#   0%|          | 0/7 [00:00<?, ?it/s]
# Percentage of the dataset used: 0.01
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.1709 | Accuracy=24.07%
# Epoch 1 Test results: Loss=4.6606 | Accuracy=14.93%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.4340 | Accuracy=53.11%
# Epoch 2 Test results: Loss=3.0056 | Accuracy=13.26%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.0841 | Accuracy=59.75%
# Epoch 3 Test results: Loss=3.9794 | Accuracy=16.78%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.8382 | Accuracy=70.12%
# Epoch 4 Test results: Loss=4.0659 | Accuracy=17.30%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.5506 | Accuracy=82.99%
# Epoch 5 Test results: Loss=4.7924 | Accuracy=14.59%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4718 | Accuracy=87.97%
# Epoch 6 Test results: Loss=5.1073 | Accuracy=20.85%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4111 | Accuracy=86.31%
# Epoch 7 Test results: Loss=3.2618 | Accuracy=32.41%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3933 | Accuracy=88.80%
# Epoch 8 Test results: Loss=2.8440 | Accuracy=35.33%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.2524 | Accuracy=92.53%
# Epoch 9 Test results: Loss=2.3305 | Accuracy=40.33%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.1252 | Accuracy=97.10%
# Epoch 10 Test results: Loss=1.9194 | Accuracy=43.89%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.1770 | Accuracy=94.61%
# Epoch 11 Test results: Loss=1.6262 | Accuracy=49.26%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0909 | Accuracy=97.10%
# Epoch 12 Test results: Loss=1.4022 | Accuracy=56.15%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.1056 | Accuracy=97.51%
# Epoch 13 Test results: Loss=1.3310 | Accuracy=59.33%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0694 | Accuracy=97.93%
# Epoch 14 Test results: Loss=1.3418 | Accuracy=60.22%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0847 | Accuracy=97.51%
# Epoch 15 Test results: Loss=1.3095 | Accuracy=60.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0840 | Accuracy=97.93%
# Epoch 16 Test results: Loss=1.2908 | Accuracy=61.63%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0994 | Accuracy=97.10%
# Epoch 17 Test results: Loss=1.2892 | Accuracy=61.93%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0911 | Accuracy=97.51%
# Epoch 18 Test results: Loss=1.2808 | Accuracy=62.26%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0646 | Accuracy=97.93%
# Epoch 19 Test results: Loss=1.2802 | Accuracy=62.15%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0554 | Accuracy=97.93%
# Epoch 20 Test results: Loss=1.2734 | Accuracy=62.52%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.9338 | Accuracy=33.95%
# Epoch 1 Test results: Loss=3.9313 | Accuracy=7.81%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.2908 | Accuracy=54.53%
# Epoch 2 Test results: Loss=3.3355 | Accuracy=24.19%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.0328 | Accuracy=65.23%
# Epoch 3 Test results: Loss=4.2025 | Accuracy=18.70%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.8718 | Accuracy=71.81%
# Epoch 4 Test results: Loss=1.9402 | Accuracy=40.74%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.7090 | Accuracy=77.16%
# Epoch 5 Test results: Loss=1.8763 | Accuracy=37.93%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.5856 | Accuracy=79.84%
# Epoch 6 Test results: Loss=1.4678 | Accuracy=51.41%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4623 | Accuracy=86.21%
# Epoch 7 Test results: Loss=1.6453 | Accuracy=53.26%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.2675 | Accuracy=92.18%
# Epoch 8 Test results: Loss=1.2254 | Accuracy=64.93%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.1861 | Accuracy=94.44%
# Epoch 9 Test results: Loss=1.1183 | Accuracy=67.00%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.1817 | Accuracy=93.42%
# Epoch 10 Test results: Loss=1.1240 | Accuracy=66.04%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.1218 | Accuracy=96.30%
# Epoch 11 Test results: Loss=1.1098 | Accuracy=66.74%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.1215 | Accuracy=96.71%
# Epoch 12 Test results: Loss=1.1198 | Accuracy=67.15%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0881 | Accuracy=97.33%
# Epoch 13 Test results: Loss=1.1310 | Accuracy=67.26%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0696 | Accuracy=98.35%
# Epoch 14 Test results: Loss=1.1403 | Accuracy=67.52%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0722 | Accuracy=98.15%
# Epoch 15 Test results: Loss=1.1481 | Accuracy=67.67%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0683 | Accuracy=99.18%
# Epoch 16 Test results: Loss=1.1559 | Accuracy=67.93%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0896 | Accuracy=98.15%
# Epoch 17 Test results: Loss=1.1611 | Accuracy=67.70%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0673 | Accuracy=98.35%
# Epoch 18 Test results: Loss=1.1603 | Accuracy=68.07%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0883 | Accuracy=98.15%
# Epoch 19 Test results: Loss=1.1493 | Accuracy=68.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0651 | Accuracy=98.35%
# Epoch 20 Test results: Loss=1.1551 | Accuracy=67.74%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.6231 | Accuracy=42.29%
# Epoch 1 Test results: Loss=5.6882 | Accuracy=20.37%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.1540 | Accuracy=58.70%
# Epoch 2 Test results: Loss=1.6440 | Accuracy=50.63%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.9874 | Accuracy=64.63%
# Epoch 3 Test results: Loss=1.6893 | Accuracy=47.41%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.8343 | Accuracy=70.98%
# Epoch 4 Test results: Loss=2.0668 | Accuracy=40.11%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.7184 | Accuracy=75.27%
# Epoch 5 Test results: Loss=1.3570 | Accuracy=59.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.6078 | Accuracy=79.97%
# Epoch 6 Test results: Loss=1.3394 | Accuracy=60.19%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.5379 | Accuracy=81.20%
# Epoch 7 Test results: Loss=1.4362 | Accuracy=53.19%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3440 | Accuracy=88.21%
# Epoch 8 Test results: Loss=0.8924 | Accuracy=70.19%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.2106 | Accuracy=92.50%
# Epoch 9 Test results: Loss=0.8499 | Accuracy=72.56%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.1676 | Accuracy=94.15%
# Epoch 10 Test results: Loss=0.8777 | Accuracy=73.07%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.1562 | Accuracy=95.38%
# Epoch 11 Test results: Loss=0.9415 | Accuracy=69.59%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.1028 | Accuracy=96.95%
# Epoch 12 Test results: Loss=0.8982 | Accuracy=73.70%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.1028 | Accuracy=97.11%
# Epoch 13 Test results: Loss=0.9835 | Accuracy=70.30%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0703 | Accuracy=97.86%
# Epoch 14 Test results: Loss=0.9381 | Accuracy=73.59%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0628 | Accuracy=98.35%
# Epoch 15 Test results: Loss=0.9338 | Accuracy=74.30%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0697 | Accuracy=97.44%
# Epoch 16 Test results: Loss=0.9357 | Accuracy=74.00%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0685 | Accuracy=98.27%
# Epoch 17 Test results: Loss=0.9420 | Accuracy=74.22%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0512 | Accuracy=98.93%
# Epoch 18 Test results: Loss=0.9443 | Accuracy=74.04%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0582 | Accuracy=98.43%
# Epoch 19 Test results: Loss=0.9444 | Accuracy=74.11%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0681 | Accuracy=98.19%
# Epoch 20 Test results: Loss=0.9575 | Accuracy=73.63%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.4448 | Accuracy=48.97%
# Epoch 1 Test results: Loss=2.5095 | Accuracy=36.59%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.0452 | Accuracy=63.05%
# Epoch 2 Test results: Loss=1.1775 | Accuracy=56.67%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.9281 | Accuracy=67.00%
# Epoch 3 Test results: Loss=1.6508 | Accuracy=50.89%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.7968 | Accuracy=72.63%
# Epoch 4 Test results: Loss=1.2244 | Accuracy=57.22%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.7262 | Accuracy=73.09%
# Epoch 5 Test results: Loss=0.8967 | Accuracy=67.15%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.6419 | Accuracy=77.00%
# Epoch 6 Test results: Loss=1.2790 | Accuracy=56.11%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.6584 | Accuracy=77.61%
# Epoch 7 Test results: Loss=1.5595 | Accuracy=53.89%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.4501 | Accuracy=84.77%
# Epoch 8 Test results: Loss=0.6109 | Accuracy=79.44%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.3234 | Accuracy=89.71%
# Epoch 9 Test results: Loss=0.6896 | Accuracy=75.85%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.2758 | Accuracy=91.32%
# Epoch 10 Test results: Loss=0.6082 | Accuracy=79.89%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.2296 | Accuracy=92.47%
# Epoch 11 Test results: Loss=0.6205 | Accuracy=79.63%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.2281 | Accuracy=92.55%
# Epoch 12 Test results: Loss=0.6285 | Accuracy=80.37%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.1993 | Accuracy=93.42%
# Epoch 13 Test results: Loss=0.6449 | Accuracy=79.81%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.1553 | Accuracy=94.49%
# Epoch 14 Test results: Loss=0.9159 | Accuracy=74.44%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.1381 | Accuracy=95.02%
# Epoch 15 Test results: Loss=0.6740 | Accuracy=80.37%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.1355 | Accuracy=95.19%
# Epoch 16 Test results: Loss=0.6795 | Accuracy=80.81%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.1345 | Accuracy=95.51%
# Epoch 17 Test results: Loss=0.6776 | Accuracy=80.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.1135 | Accuracy=96.50%
# Epoch 18 Test results: Loss=0.6894 | Accuracy=80.85%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.1144 | Accuracy=96.09%
# Epoch 19 Test results: Loss=0.6917 | Accuracy=80.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0981 | Accuracy=96.91%
# Epoch 20 Test results: Loss=0.7047 | Accuracy=80.19%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.2261 | Accuracy=56.42%
# Epoch 1 Test results: Loss=1.3676 | Accuracy=52.11%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.9519 | Accuracy=66.30%
# Epoch 2 Test results: Loss=0.8896 | Accuracy=68.52%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.7977 | Accuracy=71.73%
# Epoch 3 Test results: Loss=1.6628 | Accuracy=53.74%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.7589 | Accuracy=73.07%
# Epoch 4 Test results: Loss=1.0134 | Accuracy=65.15%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.6678 | Accuracy=76.17%
# Epoch 5 Test results: Loss=1.4095 | Accuracy=56.19%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.5986 | Accuracy=78.81%
# Epoch 6 Test results: Loss=1.2908 | Accuracy=64.48%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.6142 | Accuracy=78.50%
# Epoch 7 Test results: Loss=0.9210 | Accuracy=69.22%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3833 | Accuracy=87.53%
# Epoch 8 Test results: Loss=0.4748 | Accuracy=83.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.3083 | Accuracy=89.57%
# Epoch 9 Test results: Loss=0.4576 | Accuracy=83.59%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.2643 | Accuracy=91.01%
# Epoch 10 Test results: Loss=0.5049 | Accuracy=82.85%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.2401 | Accuracy=92.22%
# Epoch 11 Test results: Loss=0.5015 | Accuracy=82.56%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.2030 | Accuracy=93.46%
# Epoch 12 Test results: Loss=0.5460 | Accuracy=83.19%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.1838 | Accuracy=93.85%
# Epoch 13 Test results: Loss=0.6058 | Accuracy=81.26%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.1571 | Accuracy=94.61%
# Epoch 14 Test results: Loss=0.5784 | Accuracy=82.93%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.1091 | Accuracy=96.87%
# Epoch 15 Test results: Loss=0.5459 | Accuracy=84.70%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0914 | Accuracy=97.43%
# Epoch 16 Test results: Loss=0.5382 | Accuracy=85.44%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0802 | Accuracy=97.55%
# Epoch 17 Test results: Loss=0.5585 | Accuracy=84.67%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0802 | Accuracy=97.47%
# Epoch 18 Test results: Loss=0.5638 | Accuracy=84.78%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0730 | Accuracy=97.90%
# Epoch 19 Test results: Loss=0.5767 | Accuracy=84.78%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0760 | Accuracy=97.70%
# Epoch 20 Test results: Loss=0.5830 | Accuracy=85.04%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.0542 | Accuracy=62.15%
# Epoch 1 Test results: Loss=0.9281 | Accuracy=67.07%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.7730 | Accuracy=72.49%
# Epoch 2 Test results: Loss=1.0750 | Accuracy=60.41%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.6620 | Accuracy=76.80%
# Epoch 3 Test results: Loss=1.1019 | Accuracy=63.48%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.5598 | Accuracy=80.81%
# Epoch 4 Test results: Loss=1.4442 | Accuracy=58.74%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.5264 | Accuracy=81.86%
# Epoch 5 Test results: Loss=1.3738 | Accuracy=68.22%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4792 | Accuracy=83.61%
# Epoch 6 Test results: Loss=1.1858 | Accuracy=68.89%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4238 | Accuracy=85.73%
# Epoch 7 Test results: Loss=0.7574 | Accuracy=77.81%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.2515 | Accuracy=92.12%
# Epoch 8 Test results: Loss=0.3203 | Accuracy=89.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.1987 | Accuracy=93.51%
# Epoch 9 Test results: Loss=0.2998 | Accuracy=90.00%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.1739 | Accuracy=94.23%
# Epoch 10 Test results: Loss=0.2359 | Accuracy=92.00%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.1494 | Accuracy=95.09%
# Epoch 11 Test results: Loss=0.4897 | Accuracy=84.93%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.1378 | Accuracy=95.60%
# Epoch 12 Test results: Loss=0.3355 | Accuracy=88.93%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.1116 | Accuracy=96.29%
# Epoch 13 Test results: Loss=0.3126 | Accuracy=90.26%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.1025 | Accuracy=96.58%
# Epoch 14 Test results: Loss=0.2585 | Accuracy=92.11%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0659 | Accuracy=97.88%
# Epoch 15 Test results: Loss=0.2322 | Accuracy=92.93%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0507 | Accuracy=98.57%
# Epoch 16 Test results: Loss=0.2383 | Accuracy=92.93%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0470 | Accuracy=98.72%
# Epoch 17 Test results: Loss=0.2448 | Accuracy=92.96%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0453 | Accuracy=98.65%
# Epoch 18 Test results: Loss=0.2609 | Accuracy=92.93%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0403 | Accuracy=98.77%
# Epoch 19 Test results: Loss=0.2619 | Accuracy=92.96%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0400 | Accuracy=98.83%
# Epoch 20 Test results: Loss=0.2608 | Accuracy=93.19%
#
# Percentage of the dataset used: 1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.9027 | Accuracy=68.22%
# Epoch 1 Test results: Loss=1.7897 | Accuracy=53.44%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.6400 | Accuracy=77.72%
# Epoch 2 Test results: Loss=1.5562 | Accuracy=63.11%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.5377 | Accuracy=81.35%
# Epoch 3 Test results: Loss=0.7359 | Accuracy=74.89%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.4425 | Accuracy=84.86%
# Epoch 4 Test results: Loss=1.5312 | Accuracy=66.56%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.3870 | Accuracy=86.80%
# Epoch 5 Test results: Loss=0.6076 | Accuracy=78.15%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.3424 | Accuracy=88.62%
# Epoch 6 Test results: Loss=0.9786 | Accuracy=75.74%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.3076 | Accuracy=89.32%
# Epoch 7 Test results: Loss=0.5062 | Accuracy=82.70%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.1632 | Accuracy=94.80%
# Epoch 8 Test results: Loss=0.1767 | Accuracy=94.30%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.1254 | Accuracy=96.05%
# Epoch 9 Test results: Loss=0.2059 | Accuracy=92.74%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.1132 | Accuracy=96.14%
# Epoch 10 Test results: Loss=0.1606 | Accuracy=95.11%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.1004 | Accuracy=96.73%
# Epoch 11 Test results: Loss=0.2234 | Accuracy=92.48%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0851 | Accuracy=97.16%
# Epoch 12 Test results: Loss=0.2287 | Accuracy=91.48%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0670 | Accuracy=97.78%
# Epoch 13 Test results: Loss=0.1434 | Accuracy=95.74%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0639 | Accuracy=97.83%
# Epoch 14 Test results: Loss=0.1722 | Accuracy=94.04%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0420 | Accuracy=98.75%
# Epoch 15 Test results: Loss=0.1452 | Accuracy=95.56%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0315 | Accuracy=99.19%
# Epoch 16 Test results: Loss=0.1372 | Accuracy=95.96%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0320 | Accuracy=99.12%
# Epoch 17 Test results: Loss=0.1449 | Accuracy=95.74%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0280 | Accuracy=99.24%
# Epoch 18 Test results: Loss=0.1427 | Accuracy=95.81%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0281 | Accuracy=99.27%
# Epoch 19 Test results: Loss=0.1465 | Accuracy=95.70%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0250 | Accuracy=99.34%
# Epoch 20 Test results: Loss=0.1467 | Accuracy=95.78%
#
# linear_probe
#   0%|          | 0/7 [00:00<?, ?it/s]
# Percentage of the dataset used: 0.01
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.2906 | Accuracy=13.69%
# Epoch 1 Test results: Loss=2.2794 | Accuracy=14.85%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=2.1998 | Accuracy=16.18%
# Epoch 2 Test results: Loss=2.2996 | Accuracy=10.85%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=2.0731 | Accuracy=25.73%
# Epoch 3 Test results: Loss=2.2869 | Accuracy=12.63%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=2.0127 | Accuracy=31.54%
# Epoch 4 Test results: Loss=2.2690 | Accuracy=14.59%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.9690 | Accuracy=35.27%
# Epoch 5 Test results: Loss=2.2420 | Accuracy=14.96%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.8925 | Accuracy=38.17%
# Epoch 6 Test results: Loss=2.2136 | Accuracy=16.30%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.8090 | Accuracy=40.25%
# Epoch 7 Test results: Loss=2.1748 | Accuracy=19.19%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.8055 | Accuracy=40.66%
# Epoch 8 Test results: Loss=2.1177 | Accuracy=20.48%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.7777 | Accuracy=44.81%
# Epoch 9 Test results: Loss=2.0555 | Accuracy=24.41%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.7767 | Accuracy=43.98%
# Epoch 10 Test results: Loss=1.9966 | Accuracy=28.81%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.7727 | Accuracy=45.64%
# Epoch 11 Test results: Loss=1.9559 | Accuracy=31.37%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.7628 | Accuracy=42.74%
# Epoch 12 Test results: Loss=1.9226 | Accuracy=31.63%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.7704 | Accuracy=45.64%
# Epoch 13 Test results: Loss=1.8992 | Accuracy=33.78%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.7525 | Accuracy=45.64%
# Epoch 14 Test results: Loss=1.8819 | Accuracy=35.07%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.7559 | Accuracy=44.40%
# Epoch 15 Test results: Loss=1.8722 | Accuracy=35.15%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.7463 | Accuracy=45.64%
# Epoch 16 Test results: Loss=1.8644 | Accuracy=35.63%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.7506 | Accuracy=45.23%
# Epoch 17 Test results: Loss=1.8614 | Accuracy=35.70%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.7491 | Accuracy=47.30%
# Epoch 18 Test results: Loss=1.8577 | Accuracy=35.96%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.7462 | Accuracy=46.47%
# Epoch 19 Test results: Loss=1.8557 | Accuracy=36.30%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.7462 | Accuracy=43.15%
# Epoch 20 Test results: Loss=1.8558 | Accuracy=36.15%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.2650 | Accuracy=12.96%
# Epoch 1 Test results: Loss=2.2861 | Accuracy=14.22%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=2.0714 | Accuracy=24.49%
# Epoch 2 Test results: Loss=2.2665 | Accuracy=8.00%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.9620 | Accuracy=31.48%
# Epoch 3 Test results: Loss=2.1984 | Accuracy=16.74%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.8618 | Accuracy=37.04%
# Epoch 4 Test results: Loss=2.0675 | Accuracy=24.11%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.7808 | Accuracy=41.98%
# Epoch 5 Test results: Loss=1.9600 | Accuracy=32.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.7145 | Accuracy=46.71%
# Epoch 6 Test results: Loss=1.8563 | Accuracy=35.93%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.6736 | Accuracy=47.74%
# Epoch 7 Test results: Loss=1.7698 | Accuracy=40.70%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.6130 | Accuracy=50.41%
# Epoch 8 Test results: Loss=1.7457 | Accuracy=41.85%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.5973 | Accuracy=49.59%
# Epoch 9 Test results: Loss=1.7345 | Accuracy=43.37%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.5931 | Accuracy=52.88%
# Epoch 10 Test results: Loss=1.7294 | Accuracy=43.59%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.5947 | Accuracy=52.88%
# Epoch 11 Test results: Loss=1.7248 | Accuracy=44.00%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.6023 | Accuracy=52.67%
# Epoch 12 Test results: Loss=1.7218 | Accuracy=44.30%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.5896 | Accuracy=55.14%
# Epoch 13 Test results: Loss=1.7169 | Accuracy=44.56%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.5816 | Accuracy=52.88%
# Epoch 14 Test results: Loss=1.7128 | Accuracy=43.85%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.5968 | Accuracy=53.91%
# Epoch 15 Test results: Loss=1.7134 | Accuracy=43.85%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.5902 | Accuracy=54.12%
# Epoch 16 Test results: Loss=1.7135 | Accuracy=44.22%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.5721 | Accuracy=54.53%
# Epoch 17 Test results: Loss=1.7138 | Accuracy=44.07%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.5816 | Accuracy=53.50%
# Epoch 18 Test results: Loss=1.7124 | Accuracy=44.37%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.5678 | Accuracy=55.14%
# Epoch 19 Test results: Loss=1.7128 | Accuracy=44.22%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.5832 | Accuracy=54.32%
# Epoch 20 Test results: Loss=1.7127 | Accuracy=44.00%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.1721 | Accuracy=21.02%
# Epoch 1 Test results: Loss=2.2952 | Accuracy=16.30%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.9432 | Accuracy=29.76%
# Epoch 2 Test results: Loss=2.0908 | Accuracy=26.67%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.7772 | Accuracy=39.16%
# Epoch 3 Test results: Loss=1.7931 | Accuracy=36.07%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.6999 | Accuracy=41.06%
# Epoch 4 Test results: Loss=1.6925 | Accuracy=40.70%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.6449 | Accuracy=42.62%
# Epoch 5 Test results: Loss=1.6239 | Accuracy=43.93%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.5576 | Accuracy=47.24%
# Epoch 6 Test results: Loss=1.6081 | Accuracy=43.63%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.5136 | Accuracy=49.22%
# Epoch 7 Test results: Loss=1.5566 | Accuracy=45.04%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.4642 | Accuracy=51.11%
# Epoch 8 Test results: Loss=1.5397 | Accuracy=47.59%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.4641 | Accuracy=51.69%
# Epoch 9 Test results: Loss=1.5313 | Accuracy=49.04%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.4485 | Accuracy=54.41%
# Epoch 10 Test results: Loss=1.5285 | Accuracy=49.22%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.4501 | Accuracy=54.66%
# Epoch 11 Test results: Loss=1.5241 | Accuracy=49.81%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.4478 | Accuracy=53.42%
# Epoch 12 Test results: Loss=1.5254 | Accuracy=49.00%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.4461 | Accuracy=52.93%
# Epoch 13 Test results: Loss=1.5215 | Accuracy=49.26%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.4326 | Accuracy=53.75%
# Epoch 14 Test results: Loss=1.5156 | Accuracy=49.22%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.4328 | Accuracy=54.58%
# Epoch 15 Test results: Loss=1.5147 | Accuracy=49.48%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.4256 | Accuracy=54.41%
# Epoch 16 Test results: Loss=1.5134 | Accuracy=49.52%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.4281 | Accuracy=54.66%
# Epoch 17 Test results: Loss=1.5162 | Accuracy=49.44%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.4285 | Accuracy=55.48%
# Epoch 18 Test results: Loss=1.5156 | Accuracy=49.07%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.4441 | Accuracy=54.99%
# Epoch 19 Test results: Loss=1.5120 | Accuracy=49.74%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.4322 | Accuracy=54.16%
# Epoch 20 Test results: Loss=1.5162 | Accuracy=49.19%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.0787 | Accuracy=23.91%
# Epoch 1 Test results: Loss=2.0012 | Accuracy=27.78%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.7726 | Accuracy=37.41%
# Epoch 2 Test results: Loss=1.7000 | Accuracy=43.19%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.6409 | Accuracy=45.64%
# Epoch 3 Test results: Loss=1.6315 | Accuracy=43.07%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.5661 | Accuracy=46.42%
# Epoch 4 Test results: Loss=1.5646 | Accuracy=46.56%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.5120 | Accuracy=48.64%
# Epoch 5 Test results: Loss=1.5008 | Accuracy=49.41%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.4605 | Accuracy=50.74%
# Epoch 6 Test results: Loss=1.4793 | Accuracy=48.33%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.3986 | Accuracy=53.62%
# Epoch 7 Test results: Loss=1.4253 | Accuracy=52.63%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.3684 | Accuracy=56.01%
# Epoch 8 Test results: Loss=1.4151 | Accuracy=52.59%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.3487 | Accuracy=56.30%
# Epoch 9 Test results: Loss=1.4103 | Accuracy=53.04%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.3454 | Accuracy=55.97%
# Epoch 10 Test results: Loss=1.4065 | Accuracy=52.85%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.3523 | Accuracy=55.76%
# Epoch 11 Test results: Loss=1.4066 | Accuracy=53.41%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.3471 | Accuracy=56.17%
# Epoch 12 Test results: Loss=1.4019 | Accuracy=53.22%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.3356 | Accuracy=56.50%
# Epoch 13 Test results: Loss=1.4002 | Accuracy=53.04%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.3349 | Accuracy=56.54%
# Epoch 14 Test results: Loss=1.3972 | Accuracy=52.96%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.3345 | Accuracy=55.84%
# Epoch 15 Test results: Loss=1.3997 | Accuracy=52.52%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.3286 | Accuracy=56.54%
# Epoch 16 Test results: Loss=1.3945 | Accuracy=52.74%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.3297 | Accuracy=56.50%
# Epoch 17 Test results: Loss=1.3962 | Accuracy=52.78%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.3328 | Accuracy=56.01%
# Epoch 18 Test results: Loss=1.3952 | Accuracy=53.04%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.3266 | Accuracy=57.20%
# Epoch 19 Test results: Loss=1.3960 | Accuracy=52.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.3399 | Accuracy=55.60%
# Epoch 20 Test results: Loss=1.3946 | Accuracy=53.19%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.9393 | Accuracy=31.32%
# Epoch 1 Test results: Loss=1.6782 | Accuracy=42.70%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.6146 | Accuracy=44.07%
# Epoch 2 Test results: Loss=1.5094 | Accuracy=47.11%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.4948 | Accuracy=49.22%
# Epoch 3 Test results: Loss=1.4545 | Accuracy=52.00%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.4247 | Accuracy=50.16%
# Epoch 4 Test results: Loss=1.3698 | Accuracy=52.74%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.3541 | Accuracy=53.60%
# Epoch 5 Test results: Loss=1.3405 | Accuracy=51.78%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.3135 | Accuracy=55.12%
# Epoch 6 Test results: Loss=1.2960 | Accuracy=55.85%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.2879 | Accuracy=55.64%
# Epoch 7 Test results: Loss=1.2940 | Accuracy=53.15%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.2465 | Accuracy=57.51%
# Epoch 8 Test results: Loss=1.2693 | Accuracy=55.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.2394 | Accuracy=59.01%
# Epoch 9 Test results: Loss=1.2638 | Accuracy=56.11%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.2333 | Accuracy=58.60%
# Epoch 10 Test results: Loss=1.2678 | Accuracy=56.15%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.2349 | Accuracy=58.99%
# Epoch 11 Test results: Loss=1.2680 | Accuracy=54.96%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.2317 | Accuracy=58.85%
# Epoch 12 Test results: Loss=1.2628 | Accuracy=56.44%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.2275 | Accuracy=57.98%
# Epoch 13 Test results: Loss=1.2630 | Accuracy=56.19%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.2220 | Accuracy=59.57%
# Epoch 14 Test results: Loss=1.2587 | Accuracy=55.44%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.2192 | Accuracy=59.44%
# Epoch 15 Test results: Loss=1.2574 | Accuracy=56.11%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.2236 | Accuracy=59.34%
# Epoch 16 Test results: Loss=1.2616 | Accuracy=55.70%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.2225 | Accuracy=58.79%
# Epoch 17 Test results: Loss=1.2610 | Accuracy=56.04%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.2189 | Accuracy=59.01%
# Epoch 18 Test results: Loss=1.2570 | Accuracy=56.19%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.2234 | Accuracy=58.97%
# Epoch 19 Test results: Loss=1.2592 | Accuracy=55.70%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.2192 | Accuracy=59.18%
# Epoch 20 Test results: Loss=1.2564 | Accuracy=55.78%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.6931 | Accuracy=41.53%
# Epoch 1 Test results: Loss=1.4467 | Accuracy=49.67%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.4005 | Accuracy=51.36%
# Epoch 2 Test results: Loss=1.3320 | Accuracy=53.89%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.3039 | Accuracy=54.47%
# Epoch 3 Test results: Loss=1.2607 | Accuracy=56.30%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.2451 | Accuracy=56.57%
# Epoch 4 Test results: Loss=1.2297 | Accuracy=55.74%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.2029 | Accuracy=57.91%
# Epoch 5 Test results: Loss=1.2076 | Accuracy=57.15%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.1855 | Accuracy=58.24%
# Epoch 6 Test results: Loss=1.1851 | Accuracy=56.89%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.1565 | Accuracy=59.37%
# Epoch 7 Test results: Loss=1.1843 | Accuracy=57.41%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.1212 | Accuracy=61.16%
# Epoch 8 Test results: Loss=1.1578 | Accuracy=58.52%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.1139 | Accuracy=61.23%
# Epoch 9 Test results: Loss=1.1610 | Accuracy=58.30%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.1151 | Accuracy=60.82%
# Epoch 10 Test results: Loss=1.1613 | Accuracy=58.15%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.1178 | Accuracy=61.25%
# Epoch 11 Test results: Loss=1.1609 | Accuracy=58.07%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.1164 | Accuracy=61.25%
# Epoch 12 Test results: Loss=1.1607 | Accuracy=58.11%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.1108 | Accuracy=61.23%
# Epoch 13 Test results: Loss=1.1628 | Accuracy=58.33%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.1055 | Accuracy=61.23%
# Epoch 14 Test results: Loss=1.1529 | Accuracy=58.74%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.1052 | Accuracy=61.84%
# Epoch 15 Test results: Loss=1.1588 | Accuracy=57.93%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.1066 | Accuracy=61.21%
# Epoch 16 Test results: Loss=1.1551 | Accuracy=58.52%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.0981 | Accuracy=61.62%
# Epoch 17 Test results: Loss=1.1523 | Accuracy=58.41%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.1030 | Accuracy=61.54%
# Epoch 18 Test results: Loss=1.1541 | Accuracy=57.81%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.1042 | Accuracy=61.33%
# Epoch 19 Test results: Loss=1.1539 | Accuracy=57.89%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.1052 | Accuracy=61.40%
# Epoch 20 Test results: Loss=1.1541 | Accuracy=58.19%
#
# Percentage of the dataset used: 1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.6232 | Accuracy=43.44%
# Epoch 1 Test results: Loss=1.3501 | Accuracy=54.67%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.3221 | Accuracy=54.31%
# Epoch 2 Test results: Loss=1.2529 | Accuracy=54.48%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.2383 | Accuracy=56.95%
# Epoch 3 Test results: Loss=1.1980 | Accuracy=57.63%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.1915 | Accuracy=58.31%
# Epoch 4 Test results: Loss=1.1636 | Accuracy=58.44%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=1.1678 | Accuracy=58.84%
# Epoch 5 Test results: Loss=1.1612 | Accuracy=59.67%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=1.1450 | Accuracy=59.45%
# Epoch 6 Test results: Loss=1.1303 | Accuracy=59.63%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=1.1254 | Accuracy=59.98%
# Epoch 7 Test results: Loss=1.1235 | Accuracy=59.48%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=1.0919 | Accuracy=61.71%
# Epoch 8 Test results: Loss=1.1084 | Accuracy=60.19%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=1.0880 | Accuracy=61.91%
# Epoch 9 Test results: Loss=1.1091 | Accuracy=60.48%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=1.0849 | Accuracy=62.13%
# Epoch 10 Test results: Loss=1.1027 | Accuracy=60.19%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=1.0870 | Accuracy=61.65%
# Epoch 11 Test results: Loss=1.1092 | Accuracy=60.67%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=1.0872 | Accuracy=62.02%
# Epoch 12 Test results: Loss=1.1041 | Accuracy=60.70%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=1.0815 | Accuracy=61.83%
# Epoch 13 Test results: Loss=1.1085 | Accuracy=59.85%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=1.0788 | Accuracy=62.40%
# Epoch 14 Test results: Loss=1.1036 | Accuracy=60.44%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=1.0748 | Accuracy=62.22%
# Epoch 15 Test results: Loss=1.0987 | Accuracy=61.19%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=1.0802 | Accuracy=62.13%
# Epoch 16 Test results: Loss=1.1006 | Accuracy=60.74%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=1.0785 | Accuracy=62.18%
# Epoch 17 Test results: Loss=1.1019 | Accuracy=60.07%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=1.0805 | Accuracy=61.89%
# Epoch 18 Test results: Loss=1.1045 | Accuracy=60.19%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=1.0774 | Accuracy=62.04%
# Epoch 19 Test results: Loss=1.1011 | Accuracy=61.19%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=1.0782 | Accuracy=61.97%
# Epoch 20 Test results: Loss=1.1028 | Accuracy=60.70%
#
# ResNet18_Weights.IMAGENET1K_V1
#   0%|          | 0/2 [00:00<?, ?it/s]
# fine_tuning
#   0%|          | 0/7 [00:00<?, ?it/s]
# Percentage of the dataset used: 0.01
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.7763 | Accuracy=41.49%
# Epoch 1 Test results: Loss=7.3403 | Accuracy=32.26%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.5085 | Accuracy=87.97%
# Epoch 2 Test results: Loss=5.5724 | Accuracy=41.04%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.1701 | Accuracy=93.78%
# Epoch 3 Test results: Loss=3.6910 | Accuracy=36.96%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.1207 | Accuracy=95.02%
# Epoch 4 Test results: Loss=1.9257 | Accuracy=62.26%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0546 | Accuracy=99.17%
# Epoch 5 Test results: Loss=1.7419 | Accuracy=66.52%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0252 | Accuracy=99.59%
# Epoch 6 Test results: Loss=1.4411 | Accuracy=73.19%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0167 | Accuracy=99.59%
# Epoch 7 Test results: Loss=1.1834 | Accuracy=77.44%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0186 | Accuracy=99.59%
# Epoch 8 Test results: Loss=0.9139 | Accuracy=81.04%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0040 | Accuracy=100.00%
# Epoch 9 Test results: Loss=0.8013 | Accuracy=82.63%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0047 | Accuracy=100.00%
# Epoch 10 Test results: Loss=0.7485 | Accuracy=83.33%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0054 | Accuracy=100.00%
# Epoch 11 Test results: Loss=0.7245 | Accuracy=83.52%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0055 | Accuracy=100.00%
# Epoch 12 Test results: Loss=0.7048 | Accuracy=83.81%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0029 | Accuracy=100.00%
# Epoch 13 Test results: Loss=0.6900 | Accuracy=83.93%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0034 | Accuracy=100.00%
# Epoch 14 Test results: Loss=0.6794 | Accuracy=84.30%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0040 | Accuracy=100.00%
# Epoch 15 Test results: Loss=0.6865 | Accuracy=83.93%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0027 | Accuracy=100.00%
# Epoch 16 Test results: Loss=0.6854 | Accuracy=84.04%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0028 | Accuracy=100.00%
# Epoch 17 Test results: Loss=0.6858 | Accuracy=83.96%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0025 | Accuracy=100.00%
# Epoch 18 Test results: Loss=0.6855 | Accuracy=83.78%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0014 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.6807 | Accuracy=83.85%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0023 | Accuracy=100.00%
# Epoch 20 Test results: Loss=0.6840 | Accuracy=83.74%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.2000 | Accuracy=60.49%
# Epoch 1 Test results: Loss=6.0149 | Accuracy=37.41%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.3871 | Accuracy=88.48%
# Epoch 2 Test results: Loss=2.6000 | Accuracy=58.70%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.3104 | Accuracy=90.74%
# Epoch 3 Test results: Loss=1.6753 | Accuracy=66.85%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.1569 | Accuracy=94.65%
# Epoch 4 Test results: Loss=1.0466 | Accuracy=78.04%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1701 | Accuracy=95.27%
# Epoch 5 Test results: Loss=0.8864 | Accuracy=80.37%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0847 | Accuracy=97.74%
# Epoch 6 Test results: Loss=0.8748 | Accuracy=80.26%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0956 | Accuracy=97.33%
# Epoch 7 Test results: Loss=1.2210 | Accuracy=74.41%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0537 | Accuracy=98.77%
# Epoch 8 Test results: Loss=0.6320 | Accuracy=84.48%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0165 | Accuracy=99.59%
# Epoch 9 Test results: Loss=0.5401 | Accuracy=86.26%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0242 | Accuracy=99.38%
# Epoch 10 Test results: Loss=0.5118 | Accuracy=87.00%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0062 | Accuracy=99.79%
# Epoch 11 Test results: Loss=0.5015 | Accuracy=87.30%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0079 | Accuracy=100.00%
# Epoch 12 Test results: Loss=0.4984 | Accuracy=87.26%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0058 | Accuracy=100.00%
# Epoch 13 Test results: Loss=0.4916 | Accuracy=87.52%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0058 | Accuracy=100.00%
# Epoch 14 Test results: Loss=0.4911 | Accuracy=87.59%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0170 | Accuracy=99.59%
# Epoch 15 Test results: Loss=0.4929 | Accuracy=87.81%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0093 | Accuracy=99.79%
# Epoch 16 Test results: Loss=0.4933 | Accuracy=87.70%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0237 | Accuracy=99.38%
# Epoch 17 Test results: Loss=0.4848 | Accuracy=87.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0155 | Accuracy=99.59%
# Epoch 18 Test results: Loss=0.4911 | Accuracy=87.70%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0052 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.4868 | Accuracy=87.96%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0199 | Accuracy=99.59%
# Epoch 20 Test results: Loss=0.4799 | Accuracy=88.00%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.0076 | Accuracy=71.89%
# Epoch 1 Test results: Loss=6.6503 | Accuracy=40.15%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.4568 | Accuracy=85.90%
# Epoch 2 Test results: Loss=0.6733 | Accuracy=81.74%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2688 | Accuracy=91.67%
# Epoch 3 Test results: Loss=0.7094 | Accuracy=82.37%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.1446 | Accuracy=96.37%
# Epoch 4 Test results: Loss=0.4004 | Accuracy=88.44%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1296 | Accuracy=96.21%
# Epoch 5 Test results: Loss=0.3696 | Accuracy=89.07%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1327 | Accuracy=96.21%
# Epoch 6 Test results: Loss=0.6158 | Accuracy=84.15%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0981 | Accuracy=97.20%
# Epoch 7 Test results: Loss=0.4561 | Accuracy=86.52%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0534 | Accuracy=98.10%
# Epoch 8 Test results: Loss=0.3049 | Accuracy=91.93%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0319 | Accuracy=99.18%
# Epoch 9 Test results: Loss=0.2752 | Accuracy=92.15%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0176 | Accuracy=99.75%
# Epoch 10 Test results: Loss=0.2596 | Accuracy=92.26%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0129 | Accuracy=99.84%
# Epoch 11 Test results: Loss=0.2546 | Accuracy=92.56%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0135 | Accuracy=99.75%
# Epoch 12 Test results: Loss=0.2571 | Accuracy=92.89%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0138 | Accuracy=99.67%
# Epoch 13 Test results: Loss=0.2541 | Accuracy=92.70%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0071 | Accuracy=99.92%
# Epoch 14 Test results: Loss=0.2519 | Accuracy=92.85%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0059 | Accuracy=99.92%
# Epoch 15 Test results: Loss=0.2553 | Accuracy=92.81%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0076 | Accuracy=99.84%
# Epoch 16 Test results: Loss=0.2559 | Accuracy=92.74%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0122 | Accuracy=99.75%
# Epoch 17 Test results: Loss=0.2539 | Accuracy=92.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0154 | Accuracy=99.75%
# Epoch 18 Test results: Loss=0.2513 | Accuracy=92.96%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0112 | Accuracy=99.67%
# Epoch 19 Test results: Loss=0.2570 | Accuracy=92.89%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0108 | Accuracy=99.67%
# Epoch 20 Test results: Loss=0.2506 | Accuracy=93.19%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.6701 | Accuracy=78.97%
# Epoch 1 Test results: Loss=0.9445 | Accuracy=73.74%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.3662 | Accuracy=88.72%
# Epoch 2 Test results: Loss=0.3489 | Accuracy=88.52%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2200 | Accuracy=93.05%
# Epoch 3 Test results: Loss=0.3760 | Accuracy=88.26%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.2036 | Accuracy=93.74%
# Epoch 4 Test results: Loss=0.3437 | Accuracy=89.37%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1706 | Accuracy=94.49%
# Epoch 5 Test results: Loss=0.4496 | Accuracy=87.33%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1248 | Accuracy=96.21%
# Epoch 6 Test results: Loss=0.6813 | Accuracy=82.89%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1578 | Accuracy=95.68%
# Epoch 7 Test results: Loss=0.6031 | Accuracy=84.78%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.1190 | Accuracy=96.75%
# Epoch 8 Test results: Loss=0.2282 | Accuracy=92.96%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0337 | Accuracy=99.14%
# Epoch 9 Test results: Loss=0.2040 | Accuracy=94.15%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0222 | Accuracy=99.59%
# Epoch 10 Test results: Loss=0.2006 | Accuracy=94.22%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0217 | Accuracy=99.51%
# Epoch 11 Test results: Loss=0.2088 | Accuracy=94.11%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0163 | Accuracy=99.59%
# Epoch 12 Test results: Loss=0.1979 | Accuracy=94.48%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0146 | Accuracy=99.67%
# Epoch 13 Test results: Loss=0.2091 | Accuracy=94.15%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0118 | Accuracy=99.75%
# Epoch 14 Test results: Loss=0.2039 | Accuracy=94.30%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0092 | Accuracy=99.79%
# Epoch 15 Test results: Loss=0.2039 | Accuracy=94.41%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0115 | Accuracy=99.71%
# Epoch 16 Test results: Loss=0.2060 | Accuracy=94.22%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0082 | Accuracy=99.84%
# Epoch 17 Test results: Loss=0.2023 | Accuracy=94.41%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0106 | Accuracy=99.71%
# Epoch 18 Test results: Loss=0.2009 | Accuracy=94.63%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0087 | Accuracy=99.79%
# Epoch 19 Test results: Loss=0.2036 | Accuracy=94.52%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0044 | Accuracy=100.00%
# Epoch 20 Test results: Loss=0.2018 | Accuracy=94.44%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.6186 | Accuracy=81.26%
# Epoch 1 Test results: Loss=0.3894 | Accuracy=88.15%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.2525 | Accuracy=91.98%
# Epoch 2 Test results: Loss=0.4111 | Accuracy=87.30%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2218 | Accuracy=93.15%
# Epoch 3 Test results: Loss=0.5009 | Accuracy=86.59%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.2426 | Accuracy=92.72%
# Epoch 4 Test results: Loss=0.9792 | Accuracy=77.52%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1892 | Accuracy=94.01%
# Epoch 5 Test results: Loss=0.3130 | Accuracy=90.93%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1297 | Accuracy=96.13%
# Epoch 6 Test results: Loss=0.4290 | Accuracy=87.89%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1484 | Accuracy=95.33%
# Epoch 7 Test results: Loss=0.3348 | Accuracy=88.85%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0556 | Accuracy=98.27%
# Epoch 8 Test results: Loss=0.1590 | Accuracy=95.26%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0277 | Accuracy=99.03%
# Epoch 9 Test results: Loss=0.1572 | Accuracy=95.22%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0181 | Accuracy=99.57%
# Epoch 10 Test results: Loss=0.1553 | Accuracy=95.48%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0163 | Accuracy=99.47%
# Epoch 11 Test results: Loss=0.1499 | Accuracy=95.44%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0112 | Accuracy=99.73%
# Epoch 12 Test results: Loss=0.1498 | Accuracy=95.52%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0104 | Accuracy=99.71%
# Epoch 13 Test results: Loss=0.1529 | Accuracy=95.37%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0073 | Accuracy=99.88%
# Epoch 14 Test results: Loss=0.1458 | Accuracy=96.00%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0089 | Accuracy=99.77%
# Epoch 15 Test results: Loss=0.1509 | Accuracy=95.70%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0091 | Accuracy=99.69%
# Epoch 16 Test results: Loss=0.1519 | Accuracy=95.59%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0069 | Accuracy=99.86%
# Epoch 17 Test results: Loss=0.1490 | Accuracy=95.74%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0057 | Accuracy=99.90%
# Epoch 18 Test results: Loss=0.1522 | Accuracy=95.81%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0061 | Accuracy=99.92%
# Epoch 19 Test results: Loss=0.1519 | Accuracy=95.85%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0054 | Accuracy=99.88%
# Epoch 20 Test results: Loss=0.1533 | Accuracy=95.63%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.4566 | Accuracy=85.63%
# Epoch 1 Test results: Loss=0.2788 | Accuracy=90.52%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.2547 | Accuracy=91.76%
# Epoch 2 Test results: Loss=0.4245 | Accuracy=88.11%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2228 | Accuracy=92.95%
# Epoch 3 Test results: Loss=0.2354 | Accuracy=92.22%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.1926 | Accuracy=93.85%
# Epoch 4 Test results: Loss=1.2163 | Accuracy=80.63%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1808 | Accuracy=94.44%
# Epoch 5 Test results: Loss=0.3173 | Accuracy=90.19%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1550 | Accuracy=94.95%
# Epoch 6 Test results: Loss=0.2828 | Accuracy=91.26%
#
# ...
# Epoch 11 Test results: Loss=1.3908 | Accuracy=62.30%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.8889 | Accuracy=86.31%
# Epoch 12 Test results: Loss=1.3884 | Accuracy=62.44%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.9055 | Accuracy=82.99%
# Epoch 13 Test results: Loss=1.3833 | Accuracy=62.48%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.8636 | Accuracy=86.72%
# Epoch 14 Test results: Loss=1.3727 | Accuracy=62.67%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.8251 | Accuracy=90.87%
# Epoch 15 Test results: Loss=1.3733 | Accuracy=62.81%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.8832 | Accuracy=86.72%
# Epoch 16 Test results: Loss=1.3685 | Accuracy=62.78%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.8655 | Accuracy=86.31%
# Epoch 17 Test results: Loss=1.3717 | Accuracy=62.63%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.8431 | Accuracy=86.31%
# Epoch 18 Test results: Loss=1.3716 | Accuracy=62.93%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.8588 | Accuracy=85.48%
# Epoch 19 Test results: Loss=1.3726 | Accuracy=62.81%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.8637 | Accuracy=85.48%
# Epoch 20 Test results: Loss=1.3743 | Accuracy=63.00%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.3380 | Accuracy=18.72%
# Epoch 1 Test results: Loss=1.9765 | Accuracy=32.52%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.8031 | Accuracy=38.68%
# Epoch 2 Test results: Loss=1.6685 | Accuracy=53.04%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.4736 | Accuracy=61.32%
# Epoch 3 Test results: Loss=1.4469 | Accuracy=61.67%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=1.1792 | Accuracy=73.05%
# Epoch 4 Test results: Loss=1.2817 | Accuracy=66.07%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.9977 | Accuracy=76.95%
# Epoch 5 Test results: Loss=1.1599 | Accuracy=69.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.8396 | Accuracy=79.63%
# Epoch 6 Test results: Loss=1.0847 | Accuracy=71.00%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.7420 | Accuracy=83.95%
# Epoch 7 Test results: Loss=1.0173 | Accuracy=71.67%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.6810 | Accuracy=86.21%
# Epoch 8 Test results: Loss=1.0063 | Accuracy=71.96%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.6948 | Accuracy=87.04%
# Epoch 9 Test results: Loss=1.0062 | Accuracy=71.67%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.6672 | Accuracy=87.04%
# Epoch 10 Test results: Loss=1.0099 | Accuracy=71.81%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.6538 | Accuracy=87.24%
# Epoch 11 Test results: Loss=1.0078 | Accuracy=72.00%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.6804 | Accuracy=84.77%
# Epoch 12 Test results: Loss=1.0016 | Accuracy=72.15%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.6780 | Accuracy=86.21%
# Epoch 13 Test results: Loss=0.9959 | Accuracy=72.33%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.6731 | Accuracy=87.24%
# Epoch 14 Test results: Loss=0.9911 | Accuracy=72.63%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.6526 | Accuracy=87.04%
# Epoch 15 Test results: Loss=0.9862 | Accuracy=72.41%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.6434 | Accuracy=85.80%
# Epoch 16 Test results: Loss=0.9832 | Accuracy=72.59%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.6381 | Accuracy=86.42%
# Epoch 17 Test results: Loss=0.9863 | Accuracy=72.63%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.6378 | Accuracy=87.04%
# Epoch 18 Test results: Loss=0.9851 | Accuracy=72.85%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.6589 | Accuracy=87.04%
# Epoch 19 Test results: Loss=0.9896 | Accuracy=72.81%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.6369 | Accuracy=85.80%
# Epoch 20 Test results: Loss=0.9900 | Accuracy=72.59%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.2279 | Accuracy=21.10%
# Epoch 1 Test results: Loss=1.6867 | Accuracy=52.04%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.4212 | Accuracy=62.32%
# Epoch 2 Test results: Loss=1.2286 | Accuracy=68.44%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.0513 | Accuracy=74.53%
# Epoch 3 Test results: Loss=0.9989 | Accuracy=74.44%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.8434 | Accuracy=79.31%
# Epoch 4 Test results: Loss=0.8776 | Accuracy=77.07%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.7263 | Accuracy=82.28%
# Epoch 5 Test results: Loss=0.8039 | Accuracy=77.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.6287 | Accuracy=83.84%
# Epoch 6 Test results: Loss=0.7630 | Accuracy=78.52%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.5850 | Accuracy=84.67%
# Epoch 7 Test results: Loss=0.7199 | Accuracy=79.78%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.5220 | Accuracy=87.47%
# Epoch 8 Test results: Loss=0.7147 | Accuracy=79.74%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.5234 | Accuracy=87.39%
# Epoch 9 Test results: Loss=0.7033 | Accuracy=80.19%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.4989 | Accuracy=88.38%
# Epoch 10 Test results: Loss=0.7103 | Accuracy=79.93%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.4909 | Accuracy=88.54%
# Epoch 11 Test results: Loss=0.7059 | Accuracy=80.15%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.4901 | Accuracy=88.62%
# Epoch 12 Test results: Loss=0.7031 | Accuracy=80.22%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.5008 | Accuracy=88.54%
# Epoch 13 Test results: Loss=0.6955 | Accuracy=80.19%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.4941 | Accuracy=87.80%
# Epoch 14 Test results: Loss=0.6927 | Accuracy=79.93%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.4875 | Accuracy=88.46%
# Epoch 15 Test results: Loss=0.6907 | Accuracy=80.30%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.4715 | Accuracy=88.87%
# Epoch 16 Test results: Loss=0.6954 | Accuracy=79.78%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.4774 | Accuracy=88.62%
# Epoch 17 Test results: Loss=0.6957 | Accuracy=80.15%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.4687 | Accuracy=88.54%
# Epoch 18 Test results: Loss=0.6899 | Accuracy=80.33%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.4765 | Accuracy=88.62%
# Epoch 19 Test results: Loss=0.6950 | Accuracy=80.15%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.4764 | Accuracy=89.78%
# Epoch 20 Test results: Loss=0.6930 | Accuracy=80.37%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.7771 | Accuracy=42.18%
# Epoch 1 Test results: Loss=1.2040 | Accuracy=69.22%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.9660 | Accuracy=74.98%
# Epoch 2 Test results: Loss=0.8659 | Accuracy=76.30%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.7430 | Accuracy=79.71%
# Epoch 3 Test results: Loss=0.7296 | Accuracy=79.48%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.6339 | Accuracy=81.77%
# Epoch 4 Test results: Loss=0.6762 | Accuracy=79.81%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.5590 | Accuracy=84.20%
# Epoch 5 Test results: Loss=0.6485 | Accuracy=80.63%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.5158 | Accuracy=85.60%
# Epoch 6 Test results: Loss=0.6439 | Accuracy=80.33%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4748 | Accuracy=85.64%
# Epoch 7 Test results: Loss=0.6072 | Accuracy=81.26%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.4372 | Accuracy=87.12%
# Epoch 8 Test results: Loss=0.5985 | Accuracy=81.44%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.4261 | Accuracy=88.27%
# Epoch 9 Test results: Loss=0.5975 | Accuracy=81.56%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.4392 | Accuracy=87.82%
# Epoch 10 Test results: Loss=0.5863 | Accuracy=82.04%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.4310 | Accuracy=87.65%
# Epoch 11 Test results: Loss=0.5909 | Accuracy=81.78%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.4133 | Accuracy=87.90%
# Epoch 12 Test results: Loss=0.5969 | Accuracy=81.19%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.4345 | Accuracy=86.95%
# Epoch 13 Test results: Loss=0.5831 | Accuracy=82.41%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.4198 | Accuracy=87.20%
# Epoch 14 Test results: Loss=0.5852 | Accuracy=82.26%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.4075 | Accuracy=88.68%
# Epoch 15 Test results: Loss=0.5828 | Accuracy=82.07%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.4123 | Accuracy=88.48%
# Epoch 16 Test results: Loss=0.5825 | Accuracy=82.00%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.4070 | Accuracy=88.44%
# Epoch 17 Test results: Loss=0.5795 | Accuracy=81.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.4106 | Accuracy=88.40%
# Epoch 18 Test results: Loss=0.5860 | Accuracy=81.93%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.4079 | Accuracy=87.98%
# Epoch 19 Test results: Loss=0.5837 | Accuracy=81.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.4152 | Accuracy=88.23%
# Epoch 20 Test results: Loss=0.5843 | Accuracy=81.70%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.4129 | Accuracy=57.74%
# Epoch 1 Test results: Loss=0.8378 | Accuracy=77.63%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.7414 | Accuracy=79.26%
# Epoch 2 Test results: Loss=0.6609 | Accuracy=81.41%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.6085 | Accuracy=82.28%
# Epoch 3 Test results: Loss=0.5931 | Accuracy=82.52%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.5366 | Accuracy=83.50%
# Epoch 4 Test results: Loss=0.5510 | Accuracy=82.89%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.4909 | Accuracy=84.69%
# Epoch 5 Test results: Loss=0.5541 | Accuracy=83.04%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4696 | Accuracy=85.19%
# Epoch 6 Test results: Loss=0.5289 | Accuracy=83.52%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4295 | Accuracy=86.69%
# Epoch 7 Test results: Loss=0.5196 | Accuracy=83.59%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3950 | Accuracy=87.33%
# Epoch 8 Test results: Loss=0.5030 | Accuracy=83.85%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.3925 | Accuracy=87.47%
# Epoch 9 Test results: Loss=0.5059 | Accuracy=83.56%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.3943 | Accuracy=87.92%
# Epoch 10 Test results: Loss=0.5058 | Accuracy=84.33%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.3811 | Accuracy=87.96%
# Epoch 11 Test results: Loss=0.5070 | Accuracy=83.96%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.3851 | Accuracy=88.50%
# Epoch 12 Test results: Loss=0.5002 | Accuracy=84.37%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.3913 | Accuracy=87.94%
# Epoch 13 Test results: Loss=0.4996 | Accuracy=83.85%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.3840 | Accuracy=88.50%
# Epoch 14 Test results: Loss=0.4990 | Accuracy=83.48%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.3820 | Accuracy=87.47%
# Epoch 15 Test results: Loss=0.5021 | Accuracy=83.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.3788 | Accuracy=87.84%
# Epoch 16 Test results: Loss=0.5056 | Accuracy=84.11%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.3757 | Accuracy=88.25%
# Epoch 17 Test results: Loss=0.4997 | Accuracy=84.37%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.3813 | Accuracy=88.09%
# Epoch 18 Test results: Loss=0.5022 | Accuracy=84.07%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.3792 | Accuracy=87.88%
# Epoch 19 Test results: Loss=0.5031 | Accuracy=83.93%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.3860 | Accuracy=87.96%
# Epoch 20 Test results: Loss=0.4984 | Accuracy=83.89%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.0357 | Accuracy=69.09%
# Epoch 1 Test results: Loss=0.6056 | Accuracy=82.19%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.5840 | Accuracy=82.26%
# Epoch 2 Test results: Loss=0.5244 | Accuracy=84.04%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.5117 | Accuracy=84.29%
# Epoch 3 Test results: Loss=0.4787 | Accuracy=85.15%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.4639 | Accuracy=85.01%
# Epoch 4 Test results: Loss=0.4713 | Accuracy=85.33%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.4443 | Accuracy=85.61%
# Epoch 5 Test results: Loss=0.4568 | Accuracy=85.30%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4330 | Accuracy=85.88%
# Epoch 6 Test results: Loss=0.4518 | Accuracy=85.48%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4120 | Accuracy=86.72%
# Epoch 7 Test results: Loss=0.4647 | Accuracy=85.22%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3897 | Accuracy=87.50%
# Epoch 8 Test results: Loss=0.4482 | Accuracy=85.67%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.3838 | Accuracy=87.49%
# Epoch 9 Test results: Loss=0.4459 | Accuracy=85.78%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.3800 | Accuracy=87.56%
# Epoch 10 Test results: Loss=0.4414 | Accuracy=85.67%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.3800 | Accuracy=87.60%
# Epoch 11 Test results: Loss=0.4486 | Accuracy=85.52%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.3759 | Accuracy=87.66%
# Epoch 12 Test results: Loss=0.4408 | Accuracy=85.67%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.3805 | Accuracy=87.37%
# Epoch 13 Test results: Loss=0.4337 | Accuracy=86.19%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.3721 | Accuracy=87.71%
# Epoch 14 Test results: Loss=0.4418 | Accuracy=86.07%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.3729 | Accuracy=87.86%
# Epoch 15 Test results: Loss=0.4437 | Accuracy=85.56%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.3717 | Accuracy=87.72%
# Epoch 16 Test results: Loss=0.4456 | Accuracy=85.48%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.3773 | Accuracy=87.72%
# Epoch 17 Test results: Loss=0.4362 | Accuracy=86.11%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.3739 | Accuracy=88.03%
# Epoch 18 Test results: Loss=0.4398 | Accuracy=86.22%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.3708 | Accuracy=87.70%
# Epoch 19 Test results: Loss=0.4388 | Accuracy=86.00%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.3740 | Accuracy=87.96%
# Epoch 20 Test results: Loss=0.4365 | Accuracy=86.30%
#
# Percentage of the dataset used: 1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.7956 | Accuracy=76.05%
# Epoch 1 Test results: Loss=0.5258 | Accuracy=83.70%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.5140 | Accuracy=83.77%
# Epoch 2 Test results: Loss=0.4676 | Accuracy=84.93%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.4696 | Accuracy=84.84%
# Epoch 3 Test results: Loss=0.4555 | Accuracy=85.15%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.4502 | Accuracy=85.36%
# Epoch 4 Test results: Loss=0.4387 | Accuracy=85.85%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.4414 | Accuracy=85.55%
# Epoch 5 Test results: Loss=0.4260 | Accuracy=86.30%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4228 | Accuracy=85.88%
# Epoch 6 Test results: Loss=0.4510 | Accuracy=85.19%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.4238 | Accuracy=85.95%
# Epoch 7 Test results: Loss=0.4262 | Accuracy=86.52%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.3840 | Accuracy=87.19%
# Epoch 8 Test results: Loss=0.4134 | Accuracy=86.67%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.3853 | Accuracy=87.50%
# Epoch 9 Test results: Loss=0.4169 | Accuracy=86.22%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.3836 | Accuracy=87.10%
# Epoch 10 Test results: Loss=0.4155 | Accuracy=86.52%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.3815 | Accuracy=87.19%
# Epoch 11 Test results: Loss=0.4166 | Accuracy=86.70%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.3861 | Accuracy=87.21%
# Epoch 12 Test results: Loss=0.4198 | Accuracy=86.37%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.3814 | Accuracy=87.33%
# Epoch 13 Test results: Loss=0.4224 | Accuracy=86.56%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.3809 | Accuracy=87.25%
# Epoch 14 Test results: Loss=0.4142 | Accuracy=86.44%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.3820 | Accuracy=87.49%
# Epoch 15 Test results: Loss=0.4174 | Accuracy=86.63%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.3747 | Accuracy=87.69%
# Epoch 16 Test results: Loss=0.4196 | Accuracy=86.52%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.3761 | Accuracy=87.49%
# Epoch 17 Test results: Loss=0.4172 | Accuracy=86.33%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.3779 | Accuracy=87.31%
# Epoch 18 Test results: Loss=0.4215 | Accuracy=86.44%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.3736 | Accuracy=87.63%
# Epoch 19 Test results: Loss=0.4198 | Accuracy=86.85%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.3856 | Accuracy=87.15%
# Epoch 20 Test results: Loss=0.4157 | Accuracy=86.85%

# %%
#save the results
import pickle
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/ResNet18/dict/train_acc_dict_percentage_resnet18.pkl", "wb") as f:
    pickle.dump(train_acc_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/ResNet18/dict/test_acc_dict_percentage_resne180.pkl", "wb") as f:
    pickle.dump(test_acc_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/ResNet18/dict/train_loss_dict_percentage_resnet18.pkl", "wb") as f:
    pickle.dump(train_loss_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/ResNet18/dict/test_loss_dict_percentage_resnet18.pkl", "wb") as f:
    pickle.dump(test_loss_dict_percentage, f)

# %%
# def tensor_list_to_numpy(_list):
#     new = []
#     for i in _list:
#         new.append(i.cpu().numpy())        
#     return np.array(new)

# train_acc_dict_percentage = tensor_list_to_numpy(train_acc_dict_percentage)
# test_acc_dict_percentage = tensor_list_to_numpy(test_acc_dict_percentage)
# train_loss_dict_percentage = tensor_list_to_numpy(train_loss_dict_percentage)
# test_loss_dict_percentage = tensor_list_to_numpy(test_loss_dict_percentage)

# %%
None_fine_tuning = []
None_linear_probe = []
Imagenetv1_fine_tuning = []
Imagenetv1_fine_tuning_linear_probe = []

for i in percentage_list:
    key = f"None_fine_tuning_{i}"
    None_fine_tuning.append(np.max(test_acc_dict_percentage[key]))
    key = f"None_linear_probe_{i}"
    None_linear_probe.append(np.max(test_acc_dict_percentage[key]))
    key = f"ResNet18_Weights.IMAGENET1K_V1_fine_tuning_{i}"
    Imagenetv1_fine_tuning.append(np.max(test_acc_dict_percentage[key]))
    key = f"ResNet18_Weights.IMAGENET1K_V1_linear_probe_{i}"
    Imagenetv1_fine_tuning_linear_probe.append(np.max(test_acc_dict_percentage[key]))

# %% [markdown]
# Plotting Graphs

# %%
#plot all the list with legend
plt.figure(figsize=(12, 8))
plt.plot(percentage_list, None_fine_tuning, label='Random Initialization (ResNet18)', marker= 'o')
plt.plot(percentage_list, Imagenetv1_fine_tuning, label='Imagenetv1 Initialization (ResNet18)', marker= 'o')
plt.xlabel('Percentage of the dataset used')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Percentage of the dataset used(Fine-tuning)[EuroSAT]')
plt.savefig('/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/figures/Accuracy vs. Percentage of the dataset used(Fine-tuning).png')

# %%
plt.figure(figsize=(12, 8))
plt.plot(percentage_list, None_linear_probe, label='Random initialization (ResNet18)', marker='o')
plt.plot(percentage_list, Imagenetv1_fine_tuning_linear_probe, label='Imagenetv1 Initialization (ResNet18)', marker='o')
plt.xlabel('Percentage of the dataset used')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Percentage of the dataset used(Linear probe)[EuroSAT]')
plt.savefig('/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/figures/Accuracy vs. Percentage of the dataset used(Linear probe).png')

# %%
import matplotlib.pyplot as plt

def plot_loss_and_accuracy(train_loss, train_accuracy, test_loss, test_accuracy, save_dir):
    epochs = range(1, len(train_loss) + 1)

    # Plot and save the loss figure
    plt.figure(figsize=(12, 8))
    plt.plot(epochs, train_loss, label='Train')
    plt.plot(epochs, test_loss, label='Test')
    plt.legend()
    plt.grid()
    plt.title('Cross Entropy Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.savefig(f'{save_dir}/loss_plot.png')

    # Plot and save the accuracy figure
    plt.figure(figsize=(12, 8))
    train_accuracy_tensor = torch.Tensor(train_accuracy)
    test_accuracy_tensor = torch.Tensor(test_accuracy)

    # Move tensors to CPU and convert to NumPy arrays
    cpu_train_accuracy = train_accuracy_tensor.cpu().numpy()
    cpu_test_accuracy = test_accuracy_tensor.cpu().numpy()
    plt.plot(epochs, cpu_train_accuracy, label='Train')
    plt.plot(epochs, cpu_test_accuracy, label='Test')
    plt.legend()
    plt.grid()
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.savefig(f'{save_dir}/accuracy_plot.png')

    # Show the plots
    plt.show()

# %% [markdown]
# Loading Best Saved Model

# %%
model.load_state_dict(torch.load("/home/idisc02/Desktop/Hewan/hlcv/Why-Self-Supervision-in-Time/src/models/final_model.pth"))
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
def get_random_test_samples(test_dataset, num_samples=20):
    random.seed(42)
    test_samples = []
    test_labels = []
    for sample, label in random.sample(list(test_dataset), k=num_samples):
        test_samples.append(sample)
        test_labels.append(label)
    return test_samples, test_labels

def make_predictions(model, data):
    predictions = []
    for sample in data:
        sample = torch.unsqueeze(sample, dim=0)

        # Convert the sample to a different data type if it is a boolean tensor
        if sample.dtype == torch.bool:
            sample = sample.float()  # Convert to float32

        # Move the input data to the same device as the model
        sample = sample.to(device)

        pred_logit = model(sample)
        pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)
        predictions.append(pred_prob.detach().cpu().numpy())
    return predictions

def get_predicted_classes(pred_probs):
    pred_probs_array = np.array(pred_probs)
    pred_probs_tensor = torch.tensor(pred_probs_array)
    pred_classes = pred_probs_tensor.argmax(dim=1)
    return pred_classes

def compare_predictions(test_labels, pred_classes, class_names):
    for true_label, pred_class in zip(test_labels, pred_classes):
        true_label_name = class_names[true_label]
        pred_label_name = class_names[pred_class]
        print(f"True Label: {true_label_name} | Predicted Label: {pred_label_name}")


# Get random test samples
test_samples, test_labels = get_random_test_samples(test_dataset, num_samples=20)

# Make predictions on test samples
pred_probs = make_predictions(model, test_samples)

# Get predicted classes
pred_classes = get_predicted_classes(pred_probs)

# Compare predictions with true labels
compare_predictions(test_labels, pred_classes, class_names)
# Out:
# True Label: SeaLake | Predicted Label: Forest
# True Label: Forest | Predicted Label: Forest
# True Label: AnnualCrop | Predicted Label: Highway
# True Label: Highway | Predicted Label: Pasture
# True Label: Highway | Predicted Label: Highway
# True Label: Highway | Predicted Label: HerbaceousVegetation
# True Label: Forest | Predicted Label: Forest
# True Label: Forest | Predicted Label: Forest
# True Label: River | Predicted Label: PermanentCrop
# True Label: Forest | Predicted Label: Forest
# True Label: SeaLake | Predicted Label: SeaLake
# True Label: PermanentCrop | Predicted Label: Pasture
# True Label: AnnualCrop | Predicted Label: AnnualCrop
# True Label: AnnualCrop | Predicted Label: AnnualCrop
# True Label: Forest | Predicted Label: Forest
# True Label: HerbaceousVegetation | Predicted Label: HerbaceousVegetation
# True Label: Highway | Predicted Label: River
# True Label: Residential | Predicted Label: Residential
# True Label: SeaLake | Predicted Label: SeaLake
# True Label: AnnualCrop | Predicted Label: Pasture

# %% [markdown]
# Displaying Outputs

# %%
def display_output_images(test_samples, pred_classes, test_labels, class_names):
    # Set the figure size and number of rows and columns
    plt.figure(figsize=(15, 15))
    nrows = 5
    ncols = 4

    for i, sample in enumerate(test_samples):
        # Create a subplot
        plt.subplot(nrows, ncols, i+1)

        # Convert the sample to a numpy array and transpose it if necessary
        image_data = sample.squeeze().cpu().numpy()

        # Ensure the image data has the correct shape
        if len(image_data.shape) == 3:
            image_data = image_data.transpose(1, 2, 0)

        # Normalize the pixel values to the range [0, 1]
        image_data = (image_data - np.min(image_data)) / (np.max(image_data) - np.min(image_data))

        # Plot the target image
        plt.imshow(image_data)

        # Find the prediction label (in text form, e.g. "Sandal")
        pred_label = class_names[pred_classes[i]]

        # Get the truth label (in text form, e.g. "T-shirt")
        truth_label = class_names[test_labels[i]] 

        # Create the title text of the plot
        title_text = f"Truth: {truth_label} | Pred: {pred_label}"

        # Check for equality and change title color accordingly
        if pred_label == truth_label:
            plt.title(title_text, fontsize=10, color="g")  # Green text if correct
        else:
            plt.title(title_text, fontsize=10, color="r")  # Red text if wrong

        plt.axis(False)

    plt.show()

# %%
# Assuming you have the necessary variables defined
display_output_images(test_samples, pred_classes, test_labels, class_names)
