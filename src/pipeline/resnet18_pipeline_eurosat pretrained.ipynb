# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import random
from tqdm.auto import tqdm
from torch.utils.data import Subset
from collections import OrderedDict
random.seed(42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset_path = '/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/data/EuroSAT'   ### Change the path when you are running the code @hewan
batch_size = 64  
num_epochs = 20  
lr = 0.001  
weight_decay = 0.0005
init_idx = 0
backbone = [models.resnet50, models.resnet18][1] # 0: resnet50, 1: resnet18
# init = [None, models.ResNet18_Weights.IMAGENET1K_V1] # 0: None, 1: IMAGENET1K_V1, 2: IMAGENET1K_V2
init = torch.load("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/pre-trained_weights/resnet18_model_dino_50k_30e.pth")
img_size = 64
training_type = ['fine_tuning', 'linear_probe']

# %%
resnet18_new = models.resnet18()
backbone_new = nn.Sequential(*list(resnet18_new.children())[:-1])
backbone_new.load_state_dict(init["resnet18_parameters"])
new_fc = nn.Linear(in_features=512, out_features=10, bias=True)
new_model = nn.Sequential(backbone_new, nn.Flatten(), new_fc)

# %% [markdown]
# TO DO:
# - Data Description, train, test split and their distribution

# %%
def select_percentage_of_train_dataset(dataset, percentage):
    class_counts = {}
    indices_by_class = {}

    # Count the number of samples in each class
    for idx, (_, label) in enumerate(dataset):
        if label not in class_counts:
            class_counts[label] = 0
            indices_by_class[label] = []
        class_counts[label] += 1
        indices_by_class[label].append(idx)

    selected_indices = []

    # Select a percentage of samples from each class
    for _, indices in indices_by_class.items():
        num_samples = int(len(indices) * percentage)
        selected_samples = random.sample(indices, num_samples)
        selected_indices.extend(selected_samples)

    selected_data = Subset(dataset, selected_indices)
    return selected_data


# def model_def(backbone, training_type, weights, num_classes, device = torch.device("cuda" if torch.cuda.is_available() else "cpu")):
#     model = backbone(weights=weights)
#     num_features = model.fc.in_features
#     model.fc = nn.Linear(num_features, num_classes)
#     if training_type == 'fine_tuning':
#         for param in model.parameters():
#             param.requires_grad = True
#     elif training_type == 'linear_probe':
#         for param in model.parameters():
#             param.requires_grad = False
#         for param in model.fc.parameters():
#             param.requires_grad = True
#     else:
#         raise ValueError('Invalid training type!')
#     return model.to(device)


def model_def(model, training_type, device = torch.device("cuda" if torch.cuda.is_available() else "cpu")):
    if training_type == 'fine_tuning':
        for param in model.parameters():
            param.requires_grad = True
    elif training_type == 'linear_probe':
        for param in model.parameters():
            param.requires_grad = False
        for param in model[2].parameters():
            param.requires_grad = True
    else:
        raise ValueError('Invalid training type!')
    return model.to(device)

def train_model(model, selected_train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir):
    train_loss = []
    train_accuracy = []
    test_loss = []
    test_accuracy = []
    best_acc = 0.0
    best_loss = float('inf')

    for epoch in range(1, num_epochs + 1):
        print(f'Epoch {epoch} of {num_epochs}')
        correct = 0
        iterations = 0
        iter_loss = 0.0

        model.train()  

        for i, (inputs, labels) in enumerate(selected_train_loader):
            if device:
                inputs = inputs.to(device)
                labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            iter_loss += loss.item() 
            optimizer.zero_grad() 
            loss.backward()  
            optimizer.step()  

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum()
            iterations += 1

        scheduler.step()

        train_loss.append(iter_loss / iterations)
        train_accuracy.append((100 * correct / len(selected_train_loader.dataset)))

        test_acc, test_losses = evaluate_model(model, test_loader, criterion, device)

        test_loss.append(test_losses)
        test_accuracy.append(test_acc)

        print(f'Epoch {epoch} Train results: Loss={train_loss[-1]:.4f} | Accuracy={train_accuracy[-1]:.2f}%')
        print(f'Epoch {epoch} Test results: Loss={test_loss[-1]:.4f} | Accuracy={test_accuracy[-1]:.2f}%\n')

        if test_acc > best_acc:
            best_acc = test_acc
            # torch.save(model.state_dict(), os.path.join(save_dir, 'best_acc_model.pth'))

        if test_losses < best_loss:
            best_loss = test_losses
            # torch.save(model.state_dict(), os.path.join(save_dir, 'best_loss_model.pth'))

    # Save the final model
    # torch.save(model.state_dict(), os.path.join(save_dir, 'final_model.pth'))

    return train_loss, train_accuracy, test_loss, test_accuracy


def evaluate_model(model, test_loader, criterion, device):
    model.eval()  
    test_loss = 0.0
    correct = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            if device:
                inputs = inputs.cuda()
                labels = labels.cuda()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100.0 * correct / len(test_loader.dataset)

    return accuracy, test_loss

# %%
#Data transforms and dataloaders
data_transforms = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


train_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'train'), data_transforms)
train_loader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
test_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'test'), data_transforms)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False, num_workers=2, pin_memory=True)

num_classes = len(train_dataset.classes)
class_names = train_dataset.classes
print("Classes:", class_names)
# Out:
# Classes: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %%
#count the number of images in each class
from collections import Counter
print(dict(Counter(test_dataset.targets)))
# Out:
# {0: 300, 1: 300, 2: 300, 3: 250, 4: 250, 5: 200, 6: 250, 7: 300, 8: 250, 9: 300}

# %%
#list with the percentage of the dataset to be used
percentage_list = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]

# %%
save_dir = "/home/idisc02/Desktop/Hewan/hlcv/Why-Self-Supervision-in-Time/src/models/weights"
train_acc_dict_percentage = {}
test_acc_dict_percentage = {}
train_loss_dict_percentage = {}
test_loss_dict_percentage = {}


for j in tqdm(training_type):
    print(j)
    for i in tqdm(range(len(percentage_list))):
        print(f'Percentage of the dataset used: {percentage_list[i]}')
        model = model_def(new_model,j, device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
        selected_train_dataset = select_percentage_of_train_dataset(train_dataset, percentage_list[i])
        selected_train_loader = DataLoader(selected_train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
        train_loss, train_accuracy, test_loss, test_accuracy = train_model(model, selected_train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, device, save_dir)

        train_acc_dict_percentage[f"DINO_30k_{j}_{percentage_list[i]}"] = train_accuracy
        test_acc_dict_percentage[f"DINO_30k_{j}_{percentage_list[i]}"] = test_accuracy
        train_loss_dict_percentage[f"DINO_30k_{j}_{percentage_list[i]}"] = train_loss
        test_loss_dict_percentage[f"DINO_30k_{j}_{percentage_list[i]}"] = test_loss
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# fine_tuning
#   0%|          | 0/7 [00:00<?, ?it/s]
# Percentage of the dataset used: 0.01
# Epoch 1 of 20
# Epoch 1 Train results: Loss=2.1791 | Accuracy=27.39%
# Epoch 1 Test results: Loss=1.8780 | Accuracy=33.41%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=1.6699 | Accuracy=56.02%
# Epoch 2 Test results: Loss=1.5396 | Accuracy=50.81%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=1.0981 | Accuracy=66.39%
# Epoch 3 Test results: Loss=1.3116 | Accuracy=54.19%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.7662 | Accuracy=73.44%
# Epoch 4 Test results: Loss=1.1053 | Accuracy=64.85%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.6088 | Accuracy=78.84%
# Epoch 5 Test results: Loss=1.0127 | Accuracy=66.59%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.4389 | Accuracy=82.99%
# Epoch 6 Test results: Loss=0.9730 | Accuracy=67.81%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.2431 | Accuracy=91.29%
# Epoch 7 Test results: Loss=1.1501 | Accuracy=57.30%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.1658 | Accuracy=95.44%
# Epoch 8 Test results: Loss=1.0392 | Accuracy=62.26%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.1801 | Accuracy=96.68%
# Epoch 9 Test results: Loss=0.9680 | Accuracy=65.44%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0996 | Accuracy=97.93%
# Epoch 10 Test results: Loss=0.9060 | Accuracy=69.15%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0792 | Accuracy=98.76%
# Epoch 11 Test results: Loss=0.8841 | Accuracy=70.85%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0732 | Accuracy=99.17%
# Epoch 12 Test results: Loss=0.8846 | Accuracy=71.19%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0954 | Accuracy=96.68%
# Epoch 13 Test results: Loss=0.8892 | Accuracy=72.07%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0455 | Accuracy=99.59%
# Epoch 14 Test results: Loss=0.9029 | Accuracy=72.00%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0547 | Accuracy=99.59%
# Epoch 15 Test results: Loss=0.9139 | Accuracy=72.30%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0447 | Accuracy=99.59%
# Epoch 16 Test results: Loss=0.9269 | Accuracy=72.22%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0409 | Accuracy=100.00%
# Epoch 17 Test results: Loss=0.9375 | Accuracy=72.26%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0443 | Accuracy=100.00%
# Epoch 18 Test results: Loss=0.9465 | Accuracy=72.07%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0348 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.9520 | Accuracy=72.19%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0603 | Accuracy=99.17%
# Epoch 20 Test results: Loss=0.9579 | Accuracy=72.15%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=1.1147 | Accuracy=63.99%
# Epoch 1 Test results: Loss=1.2969 | Accuracy=62.48%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.6742 | Accuracy=75.93%
# Epoch 2 Test results: Loss=0.9666 | Accuracy=66.41%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.5925 | Accuracy=79.63%
# Epoch 3 Test results: Loss=0.8457 | Accuracy=71.37%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.4293 | Accuracy=86.42%
# Epoch 4 Test results: Loss=1.0483 | Accuracy=66.85%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.3705 | Accuracy=85.60%
# Epoch 5 Test results: Loss=0.7414 | Accuracy=74.63%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.3357 | Accuracy=89.51%
# Epoch 6 Test results: Loss=0.9321 | Accuracy=68.48%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1678 | Accuracy=94.24%
# Epoch 7 Test results: Loss=0.8697 | Accuracy=70.44%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.1080 | Accuracy=96.71%
# Epoch 8 Test results: Loss=0.8122 | Accuracy=74.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.1173 | Accuracy=97.33%
# Epoch 9 Test results: Loss=0.7699 | Accuracy=76.11%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0544 | Accuracy=99.38%
# Epoch 10 Test results: Loss=0.7680 | Accuracy=76.30%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0628 | Accuracy=98.97%
# Epoch 11 Test results: Loss=0.7853 | Accuracy=76.04%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0566 | Accuracy=98.56%
# Epoch 12 Test results: Loss=0.8045 | Accuracy=75.78%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0451 | Accuracy=99.18%
# Epoch 13 Test results: Loss=0.8064 | Accuracy=76.07%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0256 | Accuracy=99.79%
# Epoch 14 Test results: Loss=0.8052 | Accuracy=76.56%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0390 | Accuracy=99.18%
# Epoch 15 Test results: Loss=0.8146 | Accuracy=76.22%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0454 | Accuracy=98.97%
# Epoch 16 Test results: Loss=0.8268 | Accuracy=76.04%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0488 | Accuracy=99.59%
# Epoch 17 Test results: Loss=0.8297 | Accuracy=76.37%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0511 | Accuracy=99.18%
# Epoch 18 Test results: Loss=0.8231 | Accuracy=76.33%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0260 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.8306 | Accuracy=76.19%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0257 | Accuracy=99.79%
# Epoch 20 Test results: Loss=0.8366 | Accuracy=76.11%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.9485 | Accuracy=70.32%
# Epoch 1 Test results: Loss=1.3763 | Accuracy=64.04%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.6223 | Accuracy=78.90%
# Epoch 2 Test results: Loss=0.6895 | Accuracy=75.04%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.4745 | Accuracy=82.77%
# Epoch 3 Test results: Loss=0.6347 | Accuracy=77.22%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.3233 | Accuracy=88.54%
# Epoch 4 Test results: Loss=0.8329 | Accuracy=69.93%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.2854 | Accuracy=89.69%
# Epoch 5 Test results: Loss=0.8525 | Accuracy=73.07%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.2386 | Accuracy=92.33%
# Epoch 6 Test results: Loss=1.0434 | Accuracy=69.44%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1529 | Accuracy=95.71%
# Epoch 7 Test results: Loss=1.0565 | Accuracy=69.59%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0786 | Accuracy=97.94%
# Epoch 8 Test results: Loss=0.6251 | Accuracy=81.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0563 | Accuracy=99.09%
# Epoch 9 Test results: Loss=0.6449 | Accuracy=79.89%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0442 | Accuracy=99.01%
# Epoch 10 Test results: Loss=0.6333 | Accuracy=80.30%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0279 | Accuracy=99.59%
# Epoch 11 Test results: Loss=0.6044 | Accuracy=81.59%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0206 | Accuracy=99.75%
# Epoch 12 Test results: Loss=0.6309 | Accuracy=81.85%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0304 | Accuracy=99.34%
# Epoch 13 Test results: Loss=0.6331 | Accuracy=81.70%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0274 | Accuracy=99.09%
# Epoch 14 Test results: Loss=0.6466 | Accuracy=81.52%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0235 | Accuracy=99.51%
# Epoch 15 Test results: Loss=0.6529 | Accuracy=81.93%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0209 | Accuracy=99.59%
# Epoch 16 Test results: Loss=0.6540 | Accuracy=81.89%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0157 | Accuracy=99.59%
# Epoch 17 Test results: Loss=0.6542 | Accuracy=81.74%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0186 | Accuracy=99.67%
# Epoch 18 Test results: Loss=0.6510 | Accuracy=82.07%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0106 | Accuracy=99.84%
# Epoch 19 Test results: Loss=0.6591 | Accuracy=81.85%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0137 | Accuracy=99.67%
# Epoch 20 Test results: Loss=0.6565 | Accuracy=81.81%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.7331 | Accuracy=76.71%
# Epoch 1 Test results: Loss=0.6192 | Accuracy=79.19%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.4410 | Accuracy=84.32%
# Epoch 2 Test results: Loss=0.6234 | Accuracy=78.78%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.3503 | Accuracy=88.19%
# Epoch 3 Test results: Loss=1.0923 | Accuracy=71.41%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.2626 | Accuracy=91.11%
# Epoch 4 Test results: Loss=1.1194 | Accuracy=70.59%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.2505 | Accuracy=92.47%
# Epoch 5 Test results: Loss=2.0856 | Accuracy=61.70%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1905 | Accuracy=93.87%
# Epoch 6 Test results: Loss=0.7734 | Accuracy=77.07%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1351 | Accuracy=96.26%
# Epoch 7 Test results: Loss=0.9996 | Accuracy=72.26%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0776 | Accuracy=97.90%
# Epoch 8 Test results: Loss=0.5736 | Accuracy=82.33%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0325 | Accuracy=99.47%
# Epoch 9 Test results: Loss=0.5608 | Accuracy=83.33%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0240 | Accuracy=99.67%
# Epoch 10 Test results: Loss=0.5643 | Accuracy=83.85%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0287 | Accuracy=99.51%
# Epoch 11 Test results: Loss=0.5747 | Accuracy=83.78%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0248 | Accuracy=99.55%
# Epoch 12 Test results: Loss=0.6021 | Accuracy=84.07%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0257 | Accuracy=99.26%
# Epoch 13 Test results: Loss=0.6203 | Accuracy=84.07%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0154 | Accuracy=99.71%
# Epoch 14 Test results: Loss=0.6501 | Accuracy=83.70%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0178 | Accuracy=99.42%
# Epoch 15 Test results: Loss=0.6611 | Accuracy=84.00%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0216 | Accuracy=99.47%
# Epoch 16 Test results: Loss=0.6577 | Accuracy=83.67%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0200 | Accuracy=99.55%
# Epoch 17 Test results: Loss=0.6849 | Accuracy=83.74%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0081 | Accuracy=99.88%
# Epoch 18 Test results: Loss=0.6889 | Accuracy=83.93%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0112 | Accuracy=99.79%
# Epoch 19 Test results: Loss=0.6828 | Accuracy=83.85%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0100 | Accuracy=99.71%
# Epoch 20 Test results: Loss=0.6893 | Accuracy=83.85%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.5484 | Accuracy=82.20%
# Epoch 1 Test results: Loss=0.8531 | Accuracy=73.56%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.3731 | Accuracy=87.67%
# Epoch 2 Test results: Loss=0.4322 | Accuracy=85.19%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2954 | Accuracy=89.81%
# Epoch 3 Test results: Loss=0.6296 | Accuracy=79.67%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.2256 | Accuracy=92.35%
# Epoch 4 Test results: Loss=0.5215 | Accuracy=83.26%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1973 | Accuracy=93.50%
# Epoch 5 Test results: Loss=0.5561 | Accuracy=83.56%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1449 | Accuracy=95.19%
# Epoch 6 Test results: Loss=0.5374 | Accuracy=83.74%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1788 | Accuracy=94.20%
# Epoch 7 Test results: Loss=0.5606 | Accuracy=83.59%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0652 | Accuracy=98.46%
# Epoch 8 Test results: Loss=0.3801 | Accuracy=88.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0319 | Accuracy=99.51%
# Epoch 9 Test results: Loss=0.3767 | Accuracy=88.70%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0292 | Accuracy=99.47%
# Epoch 10 Test results: Loss=0.4144 | Accuracy=87.07%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0223 | Accuracy=99.53%
# Epoch 11 Test results: Loss=0.4038 | Accuracy=88.52%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0182 | Accuracy=99.51%
# Epoch 12 Test results: Loss=0.4318 | Accuracy=88.19%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0181 | Accuracy=99.59%
# Epoch 13 Test results: Loss=0.4235 | Accuracy=88.70%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0129 | Accuracy=99.75%
# Epoch 14 Test results: Loss=0.4455 | Accuracy=88.52%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0103 | Accuracy=99.73%
# Epoch 15 Test results: Loss=0.4456 | Accuracy=88.33%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0101 | Accuracy=99.75%
# Epoch 16 Test results: Loss=0.4428 | Accuracy=88.63%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0084 | Accuracy=99.84%
# Epoch 17 Test results: Loss=0.4476 | Accuracy=88.44%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0103 | Accuracy=99.75%
# Epoch 18 Test results: Loss=0.4542 | Accuracy=88.37%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0083 | Accuracy=99.81%
# Epoch 19 Test results: Loss=0.4605 | Accuracy=88.48%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0074 | Accuracy=99.88%
# Epoch 20 Test results: Loss=0.4651 | Accuracy=88.30%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.4186 | Accuracy=86.10%
# Epoch 1 Test results: Loss=0.5402 | Accuracy=81.15%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.3066 | Accuracy=89.79%
# Epoch 2 Test results: Loss=0.3516 | Accuracy=87.70%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.2518 | Accuracy=91.37%
# Epoch 3 Test results: Loss=0.5863 | Accuracy=80.93%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.2144 | Accuracy=92.70%
# Epoch 4 Test results: Loss=0.4940 | Accuracy=84.33%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1798 | Accuracy=93.83%
# Epoch 5 Test results: Loss=0.3797 | Accuracy=88.41%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1735 | Accuracy=94.07%
# Epoch 6 Test results: Loss=0.4160 | Accuracy=86.52%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1516 | Accuracy=94.84%
# Epoch 7 Test results: Loss=0.3783 | Accuracy=87.67%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0637 | Accuracy=98.19%
# Epoch 8 Test results: Loss=0.2317 | Accuracy=92.56%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0379 | Accuracy=99.04%
# Epoch 9 Test results: Loss=0.2516 | Accuracy=92.04%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0265 | Accuracy=99.48%
# Epoch 10 Test results: Loss=0.2490 | Accuracy=92.52%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0217 | Accuracy=99.47%
# Epoch 11 Test results: Loss=0.2438 | Accuracy=92.44%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0219 | Accuracy=99.44%
# Epoch 12 Test results: Loss=0.2506 | Accuracy=92.85%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0139 | Accuracy=99.66%
# Epoch 13 Test results: Loss=0.2542 | Accuracy=92.63%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0116 | Accuracy=99.74%
# Epoch 14 Test results: Loss=0.2662 | Accuracy=92.41%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0081 | Accuracy=99.85%
# Epoch 15 Test results: Loss=0.2580 | Accuracy=92.59%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0071 | Accuracy=99.91%
# Epoch 16 Test results: Loss=0.2564 | Accuracy=92.81%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0078 | Accuracy=99.85%
# Epoch 17 Test results: Loss=0.2587 | Accuracy=92.63%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0073 | Accuracy=99.92%
# Epoch 18 Test results: Loss=0.2556 | Accuracy=92.78%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0069 | Accuracy=99.89%
# Epoch 19 Test results: Loss=0.2550 | Accuracy=93.04%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0063 | Accuracy=99.90%
# Epoch 20 Test results: Loss=0.2535 | Accuracy=92.78%
#
# Percentage of the dataset used: 1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.2485 | Accuracy=91.64%
# Epoch 1 Test results: Loss=0.2981 | Accuracy=89.48%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.2033 | Accuracy=93.14%
# Epoch 2 Test results: Loss=0.5577 | Accuracy=82.85%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.1813 | Accuracy=93.67%
# Epoch 3 Test results: Loss=0.3192 | Accuracy=89.11%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.1631 | Accuracy=94.54%
# Epoch 4 Test results: Loss=0.2936 | Accuracy=90.63%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.1433 | Accuracy=95.15%
# Epoch 5 Test results: Loss=0.4605 | Accuracy=84.85%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.1422 | Accuracy=95.15%
# Epoch 6 Test results: Loss=0.4303 | Accuracy=86.19%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.1355 | Accuracy=95.54%
# Epoch 7 Test results: Loss=0.8192 | Accuracy=79.89%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0500 | Accuracy=98.58%
# Epoch 8 Test results: Loss=0.1723 | Accuracy=94.44%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0291 | Accuracy=99.33%
# Epoch 9 Test results: Loss=0.1640 | Accuracy=94.96%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0230 | Accuracy=99.53%
# Epoch 10 Test results: Loss=0.1687 | Accuracy=94.78%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0176 | Accuracy=99.66%
# Epoch 11 Test results: Loss=0.1873 | Accuracy=94.52%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0138 | Accuracy=99.74%
# Epoch 12 Test results: Loss=0.1750 | Accuracy=94.81%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0119 | Accuracy=99.78%
# Epoch 13 Test results: Loss=0.1990 | Accuracy=94.52%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0115 | Accuracy=99.76%
# Epoch 14 Test results: Loss=0.1901 | Accuracy=94.89%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0088 | Accuracy=99.88%
# Epoch 15 Test results: Loss=0.1767 | Accuracy=94.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0070 | Accuracy=99.89%
# Epoch 16 Test results: Loss=0.1811 | Accuracy=94.78%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0071 | Accuracy=99.91%
# Epoch 17 Test results: Loss=0.1814 | Accuracy=94.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0068 | Accuracy=99.90%
# Epoch 18 Test results: Loss=0.1790 | Accuracy=95.00%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0059 | Accuracy=99.93%
# Epoch 19 Test results: Loss=0.1814 | Accuracy=95.07%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0060 | Accuracy=99.93%
# Epoch 20 Test results: Loss=0.1820 | Accuracy=95.07%
#
# linear_probe
#   0%|          | 0/7 [00:00<?, ?it/s]
# Percentage of the dataset used: 0.01
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0167 | Accuracy=99.59%
# Epoch 1 Test results: Loss=0.1821 | Accuracy=94.89%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0050 | Accuracy=100.00%
# Epoch 2 Test results: Loss=0.1829 | Accuracy=94.93%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0049 | Accuracy=100.00%
# Epoch 3 Test results: Loss=0.1827 | Accuracy=94.89%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0033 | Accuracy=100.00%
# Epoch 4 Test results: Loss=0.1832 | Accuracy=94.81%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0045 | Accuracy=100.00%
# Epoch 5 Test results: Loss=0.1837 | Accuracy=94.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0037 | Accuracy=100.00%
# Epoch 6 Test results: Loss=0.1859 | Accuracy=94.85%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0025 | Accuracy=100.00%
# Epoch 7 Test results: Loss=0.1873 | Accuracy=94.89%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0047 | Accuracy=100.00%
# Epoch 8 Test results: Loss=0.1870 | Accuracy=94.93%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0093 | Accuracy=99.59%
# Epoch 9 Test results: Loss=0.1871 | Accuracy=94.96%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0037 | Accuracy=100.00%
# Epoch 10 Test results: Loss=0.1867 | Accuracy=94.93%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0069 | Accuracy=100.00%
# Epoch 11 Test results: Loss=0.1881 | Accuracy=94.93%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0029 | Accuracy=100.00%
# Epoch 12 Test results: Loss=0.1880 | Accuracy=94.85%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0112 | Accuracy=100.00%
# Epoch 13 Test results: Loss=0.1877 | Accuracy=94.85%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0035 | Accuracy=100.00%
# Epoch 14 Test results: Loss=0.1876 | Accuracy=94.85%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0056 | Accuracy=100.00%
# Epoch 15 Test results: Loss=0.1883 | Accuracy=94.89%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0023 | Accuracy=100.00%
# Epoch 16 Test results: Loss=0.1875 | Accuracy=94.89%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0032 | Accuracy=100.00%
# Epoch 17 Test results: Loss=0.1881 | Accuracy=94.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0025 | Accuracy=100.00%
# Epoch 18 Test results: Loss=0.1885 | Accuracy=94.78%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0039 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.1882 | Accuracy=94.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0035 | Accuracy=100.00%
# Epoch 20 Test results: Loss=0.1879 | Accuracy=94.78%
#
# Percentage of the dataset used: 0.02
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0050 | Accuracy=100.00%
# Epoch 1 Test results: Loss=0.1799 | Accuracy=94.81%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0027 | Accuracy=100.00%
# Epoch 2 Test results: Loss=0.1813 | Accuracy=94.78%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0050 | Accuracy=100.00%
# Epoch 3 Test results: Loss=0.1810 | Accuracy=94.96%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0036 | Accuracy=100.00%
# Epoch 4 Test results: Loss=0.1811 | Accuracy=94.81%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0043 | Accuracy=100.00%
# Epoch 5 Test results: Loss=0.1806 | Accuracy=94.89%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0169 | Accuracy=99.59%
# Epoch 6 Test results: Loss=0.1820 | Accuracy=94.85%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0039 | Accuracy=100.00%
# Epoch 7 Test results: Loss=0.1829 | Accuracy=94.81%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0051 | Accuracy=100.00%
# Epoch 8 Test results: Loss=0.1822 | Accuracy=94.89%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0029 | Accuracy=100.00%
# Epoch 9 Test results: Loss=0.1836 | Accuracy=94.93%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0075 | Accuracy=99.79%
# Epoch 10 Test results: Loss=0.1829 | Accuracy=94.96%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0044 | Accuracy=100.00%
# Epoch 11 Test results: Loss=0.1854 | Accuracy=94.93%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0033 | Accuracy=100.00%
# Epoch 12 Test results: Loss=0.1842 | Accuracy=94.93%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0049 | Accuracy=100.00%
# Epoch 13 Test results: Loss=0.1838 | Accuracy=94.81%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0042 | Accuracy=100.00%
# Epoch 14 Test results: Loss=0.1841 | Accuracy=94.78%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0045 | Accuracy=100.00%
# Epoch 15 Test results: Loss=0.1841 | Accuracy=94.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0043 | Accuracy=100.00%
# Epoch 16 Test results: Loss=0.1842 | Accuracy=94.85%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0030 | Accuracy=100.00%
# Epoch 17 Test results: Loss=0.1844 | Accuracy=94.89%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0043 | Accuracy=100.00%
# Epoch 18 Test results: Loss=0.1839 | Accuracy=94.93%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0064 | Accuracy=99.79%
# Epoch 19 Test results: Loss=0.1835 | Accuracy=94.67%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0044 | Accuracy=100.00%
# Epoch 20 Test results: Loss=0.1834 | Accuracy=94.67%
#
# Percentage of the dataset used: 0.05
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0059 | Accuracy=99.92%
# Epoch 1 Test results: Loss=0.1829 | Accuracy=94.74%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0042 | Accuracy=100.00%
# Epoch 2 Test results: Loss=0.1846 | Accuracy=94.96%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0041 | Accuracy=100.00%
# Epoch 3 Test results: Loss=0.1867 | Accuracy=94.89%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0033 | Accuracy=100.00%
# Epoch 4 Test results: Loss=0.1876 | Accuracy=94.85%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0038 | Accuracy=100.00%
# Epoch 5 Test results: Loss=0.1838 | Accuracy=95.19%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0040 | Accuracy=99.92%
# Epoch 6 Test results: Loss=0.1871 | Accuracy=94.93%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0032 | Accuracy=100.00%
# Epoch 7 Test results: Loss=0.1897 | Accuracy=94.85%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0052 | Accuracy=100.00%
# Epoch 8 Test results: Loss=0.1887 | Accuracy=95.00%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0060 | Accuracy=100.00%
# Epoch 9 Test results: Loss=0.1880 | Accuracy=95.00%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0040 | Accuracy=100.00%
# Epoch 10 Test results: Loss=0.1879 | Accuracy=94.85%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0031 | Accuracy=100.00%
# Epoch 11 Test results: Loss=0.1887 | Accuracy=94.85%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0037 | Accuracy=100.00%
# Epoch 12 Test results: Loss=0.1868 | Accuracy=95.11%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0046 | Accuracy=100.00%
# Epoch 13 Test results: Loss=0.1867 | Accuracy=94.93%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0056 | Accuracy=100.00%
# Epoch 14 Test results: Loss=0.1876 | Accuracy=95.00%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0034 | Accuracy=100.00%
# Epoch 15 Test results: Loss=0.1881 | Accuracy=94.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0036 | Accuracy=100.00%
# Epoch 16 Test results: Loss=0.1873 | Accuracy=95.11%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0049 | Accuracy=99.92%
# Epoch 17 Test results: Loss=0.1871 | Accuracy=95.19%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0032 | Accuracy=100.00%
# Epoch 18 Test results: Loss=0.1880 | Accuracy=94.89%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0031 | Accuracy=100.00%
# Epoch 19 Test results: Loss=0.1871 | Accuracy=94.96%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0049 | Accuracy=99.92%
# Epoch 20 Test results: Loss=0.1876 | Accuracy=94.96%
#
# Percentage of the dataset used: 0.1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0063 | Accuracy=99.96%
# Epoch 1 Test results: Loss=0.1895 | Accuracy=94.81%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0062 | Accuracy=99.92%
# Epoch 2 Test results: Loss=0.1886 | Accuracy=94.85%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0052 | Accuracy=99.96%
# Epoch 3 Test results: Loss=0.1898 | Accuracy=94.85%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0052 | Accuracy=99.88%
# Epoch 4 Test results: Loss=0.1892 | Accuracy=94.85%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0043 | Accuracy=99.96%
# Epoch 5 Test results: Loss=0.1889 | Accuracy=95.00%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0059 | Accuracy=99.96%
# Epoch 6 Test results: Loss=0.1903 | Accuracy=94.96%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0051 | Accuracy=99.92%
# Epoch 7 Test results: Loss=0.1904 | Accuracy=94.93%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0046 | Accuracy=99.96%
# Epoch 8 Test results: Loss=0.1911 | Accuracy=94.74%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0051 | Accuracy=100.00%
# Epoch 9 Test results: Loss=0.1918 | Accuracy=95.00%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0050 | Accuracy=99.96%
# Epoch 10 Test results: Loss=0.1880 | Accuracy=94.96%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0037 | Accuracy=100.00%
# Epoch 11 Test results: Loss=0.1893 | Accuracy=94.89%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0041 | Accuracy=99.96%
# Epoch 12 Test results: Loss=0.1881 | Accuracy=94.93%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0050 | Accuracy=99.92%
# Epoch 13 Test results: Loss=0.1912 | Accuracy=94.85%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0052 | Accuracy=99.96%
# Epoch 14 Test results: Loss=0.1875 | Accuracy=94.96%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0047 | Accuracy=99.96%
# Epoch 15 Test results: Loss=0.1904 | Accuracy=94.70%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0040 | Accuracy=99.96%
# Epoch 16 Test results: Loss=0.1881 | Accuracy=95.04%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0042 | Accuracy=99.96%
# Epoch 17 Test results: Loss=0.1869 | Accuracy=95.04%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0048 | Accuracy=99.92%
# Epoch 18 Test results: Loss=0.1868 | Accuracy=94.96%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0041 | Accuracy=99.96%
# Epoch 19 Test results: Loss=0.1904 | Accuracy=94.89%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0036 | Accuracy=100.00%
# Epoch 20 Test results: Loss=0.1875 | Accuracy=94.89%
#
# Percentage of the dataset used: 0.2
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0057 | Accuracy=99.96%
# Epoch 1 Test results: Loss=0.1905 | Accuracy=94.85%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0053 | Accuracy=99.96%
# Epoch 2 Test results: Loss=0.1974 | Accuracy=94.81%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0054 | Accuracy=99.96%
# Epoch 3 Test results: Loss=0.1927 | Accuracy=94.78%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0051 | Accuracy=99.94%
# Epoch 4 Test results: Loss=0.1887 | Accuracy=95.00%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0053 | Accuracy=99.98%
# Epoch 5 Test results: Loss=0.1969 | Accuracy=95.00%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0068 | Accuracy=99.86%
# Epoch 6 Test results: Loss=0.1993 | Accuracy=94.81%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0055 | Accuracy=99.92%
# Epoch 7 Test results: Loss=0.1976 | Accuracy=94.96%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0046 | Accuracy=99.98%
# Epoch 8 Test results: Loss=0.1971 | Accuracy=95.04%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0049 | Accuracy=99.92%
# Epoch 9 Test results: Loss=0.1972 | Accuracy=94.93%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0067 | Accuracy=99.88%
# Epoch 10 Test results: Loss=0.1970 | Accuracy=95.07%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0042 | Accuracy=99.98%
# Epoch 11 Test results: Loss=0.1913 | Accuracy=94.81%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0049 | Accuracy=99.94%
# Epoch 12 Test results: Loss=0.1948 | Accuracy=95.04%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0065 | Accuracy=99.90%
# Epoch 13 Test results: Loss=0.1918 | Accuracy=95.19%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0047 | Accuracy=99.94%
# Epoch 14 Test results: Loss=0.1955 | Accuracy=94.96%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0058 | Accuracy=99.90%
# Epoch 15 Test results: Loss=0.1928 | Accuracy=94.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0037 | Accuracy=99.94%
# Epoch 16 Test results: Loss=0.1954 | Accuracy=94.96%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0068 | Accuracy=99.90%
# Epoch 17 Test results: Loss=0.1941 | Accuracy=94.96%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0063 | Accuracy=99.96%
# Epoch 18 Test results: Loss=0.1932 | Accuracy=94.96%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0058 | Accuracy=99.92%
# Epoch 19 Test results: Loss=0.1921 | Accuracy=95.26%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0041 | Accuracy=99.98%
# Epoch 20 Test results: Loss=0.1927 | Accuracy=95.15%
#
# Percentage of the dataset used: 0.5
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0056 | Accuracy=99.93%
# Epoch 1 Test results: Loss=0.1910 | Accuracy=94.93%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0051 | Accuracy=99.91%
# Epoch 2 Test results: Loss=0.1954 | Accuracy=94.89%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0057 | Accuracy=99.94%
# Epoch 3 Test results: Loss=0.1932 | Accuracy=95.00%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0062 | Accuracy=99.89%
# Epoch 4 Test results: Loss=0.1965 | Accuracy=94.81%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0067 | Accuracy=99.88%
# Epoch 5 Test results: Loss=0.1977 | Accuracy=94.93%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0056 | Accuracy=99.93%
# Epoch 6 Test results: Loss=0.1940 | Accuracy=94.93%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0054 | Accuracy=99.94%
# Epoch 7 Test results: Loss=0.1952 | Accuracy=95.07%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0067 | Accuracy=99.91%
# Epoch 8 Test results: Loss=0.1928 | Accuracy=95.11%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0059 | Accuracy=99.87%
# Epoch 9 Test results: Loss=0.1928 | Accuracy=95.11%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0059 | Accuracy=99.93%
# Epoch 10 Test results: Loss=0.1958 | Accuracy=95.04%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0047 | Accuracy=99.93%
# Epoch 11 Test results: Loss=0.1956 | Accuracy=94.96%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0049 | Accuracy=99.94%
# Epoch 12 Test results: Loss=0.2017 | Accuracy=94.85%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0054 | Accuracy=99.93%
# Epoch 13 Test results: Loss=0.1934 | Accuracy=95.15%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0054 | Accuracy=99.91%
# Epoch 14 Test results: Loss=0.1932 | Accuracy=95.04%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0051 | Accuracy=99.93%
# Epoch 15 Test results: Loss=0.1982 | Accuracy=94.96%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0048 | Accuracy=99.91%
# Epoch 16 Test results: Loss=0.1936 | Accuracy=94.93%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0044 | Accuracy=99.96%
# Epoch 17 Test results: Loss=0.1927 | Accuracy=95.11%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0046 | Accuracy=99.94%
# Epoch 18 Test results: Loss=0.1900 | Accuracy=95.04%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0044 | Accuracy=99.98%
# Epoch 19 Test results: Loss=0.1952 | Accuracy=94.93%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0053 | Accuracy=99.91%
# Epoch 20 Test results: Loss=0.1983 | Accuracy=94.78%
#
# Percentage of the dataset used: 1
# Epoch 1 of 20
# Epoch 1 Train results: Loss=0.0054 | Accuracy=99.94%
# Epoch 1 Test results: Loss=0.1987 | Accuracy=94.96%
#
# Epoch 2 of 20
# Epoch 2 Train results: Loss=0.0053 | Accuracy=99.91%
# Epoch 2 Test results: Loss=0.1980 | Accuracy=95.15%
#
# Epoch 3 of 20
# Epoch 3 Train results: Loss=0.0048 | Accuracy=99.94%
# Epoch 3 Test results: Loss=0.1927 | Accuracy=94.85%
#
# Epoch 4 of 20
# Epoch 4 Train results: Loss=0.0049 | Accuracy=99.94%
# Epoch 4 Test results: Loss=0.1992 | Accuracy=94.81%
#
# Epoch 5 of 20
# Epoch 5 Train results: Loss=0.0053 | Accuracy=99.94%
# Epoch 5 Test results: Loss=0.1956 | Accuracy=95.04%
#
# Epoch 6 of 20
# Epoch 6 Train results: Loss=0.0052 | Accuracy=99.95%
# Epoch 6 Test results: Loss=0.1967 | Accuracy=94.93%
#
# Epoch 7 of 20
# Epoch 7 Train results: Loss=0.0057 | Accuracy=99.91%
# Epoch 7 Test results: Loss=0.1987 | Accuracy=94.96%
#
# Epoch 8 of 20
# Epoch 8 Train results: Loss=0.0047 | Accuracy=99.94%
# Epoch 8 Test results: Loss=0.1970 | Accuracy=95.04%
#
# Epoch 9 of 20
# Epoch 9 Train results: Loss=0.0053 | Accuracy=99.93%
# Epoch 9 Test results: Loss=0.1973 | Accuracy=95.04%
#
# Epoch 10 of 20
# Epoch 10 Train results: Loss=0.0045 | Accuracy=99.96%
# Epoch 10 Test results: Loss=0.1951 | Accuracy=95.00%
#
# Epoch 11 of 20
# Epoch 11 Train results: Loss=0.0046 | Accuracy=99.95%
# Epoch 11 Test results: Loss=0.1939 | Accuracy=94.85%
#
# Epoch 12 of 20
# Epoch 12 Train results: Loss=0.0045 | Accuracy=99.93%
# Epoch 12 Test results: Loss=0.1946 | Accuracy=94.85%
#
# Epoch 13 of 20
# Epoch 13 Train results: Loss=0.0049 | Accuracy=99.94%
# Epoch 13 Test results: Loss=0.1997 | Accuracy=94.93%
#
# Epoch 14 of 20
# Epoch 14 Train results: Loss=0.0047 | Accuracy=99.94%
# Epoch 14 Test results: Loss=0.1949 | Accuracy=94.74%
#
# Epoch 15 of 20
# Epoch 15 Train results: Loss=0.0050 | Accuracy=99.93%
# Epoch 15 Test results: Loss=0.1938 | Accuracy=94.89%
#
# Epoch 16 of 20
# Epoch 16 Train results: Loss=0.0056 | Accuracy=99.92%
# Epoch 16 Test results: Loss=0.1926 | Accuracy=95.00%
#
# Epoch 17 of 20
# Epoch 17 Train results: Loss=0.0045 | Accuracy=99.94%
# Epoch 17 Test results: Loss=0.1962 | Accuracy=94.85%
#
# Epoch 18 of 20
# Epoch 18 Train results: Loss=0.0047 | Accuracy=99.95%
# Epoch 18 Test results: Loss=0.1964 | Accuracy=94.81%
#
# Epoch 19 of 20
# Epoch 19 Train results: Loss=0.0054 | Accuracy=99.93%
# Epoch 19 Test results: Loss=0.1938 | Accuracy=94.93%
#
# Epoch 20 of 20
# Epoch 20 Train results: Loss=0.0054 | Accuracy=99.92%
# Epoch 20 Test results: Loss=0.1952 | Accuracy=94.93%

# %% [markdown]
# #### Ploting results

# %%
#save the results
import pickle
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/train_acc_dict_percentage_resnet18_dino_30k.pkl", "wb") as f:
    pickle.dump(train_acc_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/test_acc_dict_percentage_resne18_dino_30k.pkl", "wb") as f:
    pickle.dump(test_acc_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/train_loss_dict_percentage_resnet18_dino_30k.pkl", "wb") as f:
    pickle.dump(train_loss_dict_percentage, f)
with open("/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/test_loss_dict_percentage_resnet18_dino_30k.pkl", "wb") as f:
    pickle.dump(test_loss_dict_percentage, f)

# %%
path2dict = "/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict"
dicts = os.listdir(path2dict)

# %%
test_acc_dict_percentage_rand_imgNet = "/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/test_acc_dict_percentage_resnet18.pkl"
with open(test_acc_dict_percentage_rand_imgNet, 'rb') as f:
    test_acc_dict_percentage_rand_imgNet = pickle.load(f)



dino_30k_test_acc = "/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/src/models/EuroSat/ResNet18/dict/test_acc_dict_percentage_resne18_dino_30k.pkl"
with open(dino_30k_test_acc, 'rb') as f:
    dino_30k_test_acc = pickle.load(f)

None_fine_tuning = []
None_linear_probe = []
Imagenetv1_fine_tuning = []
Imagenetv1_linear_probe = []
dino_30k_linear_probe = []
dino_30k_fine_tuning = []

for i in percentage_list:
    key = f"None_fine_tuning_{i}"
    None_fine_tuning.append(np.max(test_acc_dict_percentage_rand_imgNet[key]))
    key = f"None_linear_probe_{i}"
    None_linear_probe.append(np.max(test_acc_dict_percentage_rand_imgNet[key]))
    key = f"ResNet18_Weights.IMAGENET1K_V1_fine_tuning_{i}"
    Imagenetv1_fine_tuning.append(np.max(test_acc_dict_percentage_rand_imgNet[key]))
    key = f"ResNet18_Weights.IMAGENET1K_V1_linear_probe_{i}"
    Imagenetv1_linear_probe.append(np.max(test_acc_dict_percentage_rand_imgNet[key]))
    key = f"DINO_30k_fine_tuning_{i}"
    dino_30k_fine_tuning.append(np.max(dino_30k_test_acc[key]))
    key = f"DINO_30k_linear_probe_{i}"
    dino_30k_linear_probe.append(np.max(dino_30k_test_acc[key]))

# %%
#plot all the list with legend
plt.figure(figsize=(12, 8))
plt.plot(percentage_list, None_fine_tuning, label='Random Initialization (ResNet18)', marker= 'o')
plt.plot(percentage_list, dino_30k_fine_tuning, label='DINO Initialization (ResNet18)', marker= 'o')
plt.plot(percentage_list, Imagenetv1_fine_tuning, label='Imagenetv1 Initialization (ResNet18)', marker= 'o')
plt.xlabel('Percentage of the dataset used')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Percentage of the dataset used(Fine-tuning)[EuroSAT]')
plt.savefig('/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/figures/Accuracy vs. Percentage of the dataset used(Fine-tuning).png')

# %%
plt.figure(figsize=(12, 8))
plt.plot(percentage_list, None_linear_probe, label='Random initialization (ResNet18)', marker='o')
plt.plot(percentage_list, dino_30k_linear_probe, label='DINO initialization (ResNet18)', marker='o')
plt.plot(percentage_list, Imagenetv1_linear_probe, label='Imagenetv1 Initialization (ResNet18)', marker='o')
plt.xlabel('Percentage of the dataset used')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Percentage of the dataset used(Linear probe)[EuroSAT]')
plt.savefig('/home/akansh-i2sc/Desktop/Study/HLCV/Why-Self-Supervision-in-Time/figures/Accuracy vs. Percentage of the dataset used(Linear probe).png')

# %% [markdown]
# Loading Best Saved Model

# %%
model.load_state_dict(torch.load("/home/idisc02/Desktop/Hewan/hlcv/Why-Self-Supervision-in-Time/src/models/final_model.pth"))
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
def get_random_test_samples(test_dataset, num_samples=20):
    random.seed(42)
    test_samples = []
    test_labels = []
    for sample, label in random.sample(list(test_dataset), k=num_samples):
        test_samples.append(sample)
        test_labels.append(label)
    return test_samples, test_labels

def make_predictions(model, data):
    predictions = []
    for sample in data:
        sample = torch.unsqueeze(sample, dim=0)

        # Convert the sample to a different data type if it is a boolean tensor
        if sample.dtype == torch.bool:
            sample = sample.float()  # Convert to float32

        # Move the input data to the same device as the model
        sample = sample.to(device)

        pred_logit = model(sample)
        pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)
        predictions.append(pred_prob.detach().cpu().numpy())
    return predictions

def get_predicted_classes(pred_probs):
    pred_probs_array = np.array(pred_probs)
    pred_probs_tensor = torch.tensor(pred_probs_array)
    pred_classes = pred_probs_tensor.argmax(dim=1)
    return pred_classes

def compare_predictions(test_labels, pred_classes, class_names):
    for true_label, pred_class in zip(test_labels, pred_classes):
        true_label_name = class_names[true_label]
        pred_label_name = class_names[pred_class]
        print(f"True Label: {true_label_name} | Predicted Label: {pred_label_name}")


# Get random test samples
test_samples, test_labels = get_random_test_samples(test_dataset, num_samples=20)

# Make predictions on test samples
pred_probs = make_predictions(model, test_samples)

# Get predicted classes
pred_classes = get_predicted_classes(pred_probs)

# Compare predictions with true labels
compare_predictions(test_labels, pred_classes, class_names)
# Out:
# True Label: SeaLake | Predicted Label: Forest
# True Label: Forest | Predicted Label: Forest
# True Label: AnnualCrop | Predicted Label: Highway
# True Label: Highway | Predicted Label: Pasture
# True Label: Highway | Predicted Label: Highway
# True Label: Highway | Predicted Label: HerbaceousVegetation
# True Label: Forest | Predicted Label: Forest
# True Label: Forest | Predicted Label: Forest
# True Label: River | Predicted Label: PermanentCrop
# True Label: Forest | Predicted Label: Forest
# True Label: SeaLake | Predicted Label: SeaLake
# True Label: PermanentCrop | Predicted Label: Pasture
# True Label: AnnualCrop | Predicted Label: AnnualCrop
# True Label: AnnualCrop | Predicted Label: AnnualCrop
# True Label: Forest | Predicted Label: Forest
# True Label: HerbaceousVegetation | Predicted Label: HerbaceousVegetation
# True Label: Highway | Predicted Label: River
# True Label: Residential | Predicted Label: Residential
# True Label: SeaLake | Predicted Label: SeaLake
# True Label: AnnualCrop | Predicted Label: Pasture

# %% [markdown]
# Displaying Outputs

# %%
def display_output_images(test_samples, pred_classes, test_labels, class_names):
    # Set the figure size and number of rows and columns
    plt.figure(figsize=(15, 15))
    nrows = 5
    ncols = 4

    for i, sample in enumerate(test_samples):
        # Create a subplot
        plt.subplot(nrows, ncols, i+1)

        # Convert the sample to a numpy array and transpose it if necessary
        image_data = sample.squeeze().cpu().numpy()

        # Ensure the image data has the correct shape
        if len(image_data.shape) == 3:
            image_data = image_data.transpose(1, 2, 0)

        # Normalize the pixel values to the range [0, 1]
        image_data = (image_data - np.min(image_data)) / (np.max(image_data) - np.min(image_data))

        # Plot the target image
        plt.imshow(image_data)

        # Find the prediction label (in text form, e.g. "Sandal")
        pred_label = class_names[pred_classes[i]]

        # Get the truth label (in text form, e.g. "T-shirt")
        truth_label = class_names[test_labels[i]] 

        # Create the title text of the plot
        title_text = f"Truth: {truth_label} | Pred: {pred_label}"

        # Check for equality and change title color accordingly
        if pred_label == truth_label:
            plt.title(title_text, fontsize=10, color="g")  # Green text if correct
        else:
            plt.title(title_text, fontsize=10, color="r")  # Red text if wrong

        plt.axis(False)

    plt.show()

# %%
# Assuming you have the necessary variables defined
display_output_images(test_samples, pred_classes, test_labels, class_names)
